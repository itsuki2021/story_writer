# %%
import json
import os

from autogen_ext.models.openai import OpenAIChatCompletionClient
from loguru import logger

from story_writer.schemas import EventGraph, StoryPlan
from story_writer.workflow import PlanningBuilder


async def main(model_client, premise, event_graph) -> StoryPlan:
    planning_builder = PlanningBuilder(model_client=model_client)
    return await planning_builder.build_plan(premise=premise, event_graph=event_graph)


# Set up a Qwen model client
model_client = OpenAIChatCompletionClient(
    model="qwen3-235b-a22b-instruct-2507",
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
    api_key=os.environ["DASHSCOPE_API_KEY"],
    model_info={
        "vision": False,
        "function_calling": True,
        "json_output": True,
        "family": "unknown",
        "structured_output": False,
    },
    temperature=0.7,
)
premise = "A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them."
event_graph_file = "event_graph.json"

logger.add(sink="logs/{time}.log")

with open(event_graph_file, "r") as f:
    data = json.load(f)
    event_graph = EventGraph.model_validate(data)

story_plan = await main(
    model_client=model_client, premise=premise, event_graph=event_graph
)
# Out:
# 2025-09-16 14:54:59.351 | INFO     | story_writer.workflow.planning_builder:build_plan:187 - Decomposing all events into sub-events...
# 2025-09-16 14:54:59.352 | INFO     | story_writer.workflow.planning_builder:build_plan:190 - Decomposing event: E1(1/6)
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# Full Event Graph (for high-level context):
# {
#   "nodes": [
#     {
#       "event_id": "E1",
#       "title": "Campsite Under Moonlight",
#       "summary": "The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.",
#       "time": "Nightfall",
#       "location": "Rocky mountain pass",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "weary but alert"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "injured but loyal"
#         }
#       ],
#       "goal": "Rest and assess their next move",
#       "conflict": "Discovering evidence of betrayal within their ranks",
#       "novelty_score": 0.7,
#       "coherence_score": 0.95
#     },
#     {
#       "event_id": "E2",
#       "title": "Whispers in the Snow",
#       "summary": "While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.",
#       "time": "Midnight",
#       "location": "High ridge near camp",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "tense and suspicious"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "asleep, vulnerable"
#         }
#       ],
#       "goal": "Identify the source of the mysterious signals",
#       "conflict": "Paranoia and the threat of ambush by former allies",
#       "novelty_score": 0.8,
#       "coherence_score": 0.9
#     },
#     {
#       "event_id": "E3",
#       "title": "Blood Trail at Dawn",
#       "summary": "At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.",
#       "time": "Dawn",
#       "location": "Frozen ravine",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "determined and vengeful"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "weakening from injury"
#         },
#         {
#           "name": "Dying Scout",
#           "role": "messenger",
#           "state": "near death"
#         }
#       ],
#       "goal": "Uncover the truth behind the betrayal",
#       "conflict": "Race against time to survive and expose the traitor",
#       "novelty_score": 0.85,
#       "coherence_score": 0.92
#     },
#     {
#       "event_id": "E4",
#       "title": "Ambush at the Pass",
#       "summary": "As Garrick and Tarn attempt to escape the mountains with the incriminating message, they are ambushed by a covert squad led by the traitor's loyal enforcer. A brutal firefight ensues in the narrow ice gorge.",
#       "time": "Morning",
#       "location": "Ice-covered mountain pass",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "battle-hardened and desperate"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "gravely wounded but fighting"
#         },
#         {
#           "name": "Kael",
#           "role": "antagonist's enforcer",
#           "state": "ruthless and efficient"
#         }
#       ],
#       "goal": "Survive the ambush and deliver the message to loyal forces",
#       "conflict": "Direct confrontation with the traitor's forces before the truth can be exposed",
#       "novelty_score": 0.75,
#       "coherence_score": 0.93
#     },
#     {
#       "event_id": "E5",
#       "title": "Final Stand at the Beacon",
#       "summary": "Cornered at an old signal tower, Garrick uses the last of their supplies to ignite a flare, revealing both their location and the traitor's name to a distant allied outpost. Tarn sacrifices himself to hold off the attackers.",
#       "time": "Late Morning",
#       "location": "Abandoned signal tower",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "grieving but resolute"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "sacrificial, heroic"
#         },
#         {
#           "name": "Kael",
#           "role": "antagonist's enforcer",
#           "state": "overpowered by resolve"
#         }
#       ],
#       "goal": "Transmit the truth despite overwhelming odds",
#       "conflict": "Moral and physical sacrifice versus institutional betrayal",
#       "novelty_score": 0.88,
#       "coherence_score": 0.96
#     },
#     {
#       "event_id": "E6",
#       "title": "Echoes in the Hall of Records",
#       "summary": "Weeks later, Garrick stands before a military tribunal, presenting the recovered evidence. The high-ranking officer is arrested, and a formal pardon is issued for Garrick and Tarn's unit. Garrick leaves, haunted but free.",
#       "time": "One month later",
#       "location": "Capital city war council chamber",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "weary, vindicated, solitary"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "deceased, remembered"
#         },
#         {
#           "name": "High-Ranking Officer",
#           "role": "traitor",
#           "state": "arrested and disgraced"
#         }
#       ],
#       "goal": "Secure justice for the betrayed unit",
#       "conflict": "Confronting systemic corruption with irrefutable proof",
#       "novelty_score": 0.7,
#       "coherence_score": 0.94
#     }
#   ],
#   "edges": [
#     {
#       "type": "causal",
#       "source_event_id": "E1",
#       "target_event_id": "E2",
#       "rationale": "The discovery of the battalion insignia in E1 heightens Garrick's suspicion, making him more alert and attuned to anomalies during watch, which leads to his detection of coded whispers in E2."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E1",
#       "target_event_id": "E2",
#       "rationale": "E1 occurs at nightfall and sets up the campsite; E2 takes place at midnight, representing a direct chronological progression in the same location vicinity."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E2",
#       "target_event_id": "E3",
#       "rationale": "Garrick’s suspicion from overhearing coded phrases in E2 motivates the pair to remain vigilant and investigate their surroundings at dawn, leading them to discover the blood trail and dying scout in E3."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E2",
#       "target_event_id": "E3",
#       "rationale": "E2 occurs at midnight, followed by E3 at dawn, maintaining a natural time sequence as the night transitions into morning."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E3",
#       "target_event_id": "E4",
#       "rationale": "The incriminating message obtained from the dying scout in E3 reveals the identity of the traitor, prompting Garrick and Tarn to flee with the evidence—directly triggering the ambush by the traitor's forces in E4."
#     },
#     {
#       "type": "thematic",
#       "source_event_id": "E3",
#       "target_event_id": "E5",
#       "rationale": "Both events center on revealing the truth despite personal cost: E3 uncovers the betrayal through a dying messenger, while E5 culminates in transmitting that truth through sacrifice."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E4",
#       "target_event_id": "E5",
#       "rationale": "The ambush in E4 forces Garrick and Tarn into retreat, cornering them at the abandoned signal tower where they make their final stand in E5."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E4",
#       "target_event_id": "E5",
#       "rationale": "E4 takes place in the morning and directly precedes E5 in late morning, showing continuous escalation within a single day."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E5",
#       "target_event_id": "E6",
#       "rationale": "The flare launched in E5 successfully alerts allied forces, enabling Garrick to later present the evidence at the tribunal in E6, resulting in the traitor's arrest."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E5",
#       "target_event_id": "E6",
#       "rationale": "E5 concludes with the signal being sent; E6 occurs one month later, representing the delayed but logical aftermath of that transmission."
#     },
#     {
#       "type": "thematic",
#       "source_event_id": "E1",
#       "target_event_id": "E6",
#       "rationale": "Both events bookend the arc of betrayal and justice: E1 introduces the theme of internal treachery, while E6 resolves it through institutional accountability."
#     },
#     {
#       "type": "thematic",
#       "source_event_id": "E4",
#       "target_event_id": "E6",
#       "rationale": "E4 represents the peak of physical conflict against the traitor’s enforcers, while E6 represents the peak of moral and systemic confrontation—both are pivotal moments in opposing the corruption introduced earlier."
#     }
#   ]
# }
#
# TargetEventID (to expand):
# E1
#
# Requirements:
# - Generate 3-5 sub-events.
# - Focus on richness and interweave potential (e.g., setups for future events).
#
# ---------- TextMessage (subtasker_agent) ----------
# [
#   {
#     "sub_event_id": "E1_S1",
#     "parent_event_id": "E1",
#     "title": "Setting the Perimeter",
#     "summary": "Garrick methodically inspects the rocky pass for signs of recent movement, kicking aside snow to reveal disturbed earth and a partial boot print that doesn't match their unit’s pattern. He silently marks the location with a small cairn, deciding not to alert Tarn yet.",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "weary but alert"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "injured but loyal"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E1_S2",
#     "parent_event_id": "E1",
#     "title": "The Insignia in the Frost",
#     "summary": "While gathering firewood, Tarn's hand brushes against a half-frozen rock where a tarnished battalion insignia is wedged—its edges deliberately scratched, a forbidden sign of dishonor. He stares at it in silence, then pockets it, his breath shallow with dread.",
#     "characters": [
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "injured but loyal"
#       },
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "weary but alert"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E1_S3",
#     "parent_event_id": "E1",
#     "title": "Shared Silence Over Fire",
#     "summary": "The two sit by the meager flame, exchanging few words. Garrick notices Tarn’s trembling hand as he grips his side wound. When Garrick asks about the insignia, Tarn hesitates—then whispers a name: 'Varek.' Both know he was last seen commanding rear guard… hundreds of miles from this pass.",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "weary but alert"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "injured but loyal"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E1_S4",
#     "parent_event_id": "E1",
#     "title": "The Watch Begins",
#     "summary": "Garrick takes first watch, scanning the ridgeline through a cracked field glass. A flicker of motion—too smooth for wind-tossed ice—catches his eye. He adjusts focus, but sees nothing. Behind him, Tarn mutters in fevered sleep: 'Don’t trust the signal… they’re already inside.'",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "weary but alert"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "injured but loyal"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E1_S5",
#     "parent_event_id": "E1",
#     "title": "Buried Orders",
#     "summary": "Before lying down, Garrick digs into his pack and retrieves a sealed orders pouch, its wax broken. He recalls finding it on a dead courier during the retreat—a message rerouting their unit into the ambush zone, signed with his own commander’s seal. He burns it without speaking, watching the ash rise like guilt.",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "weary but alert"
#       }
#     ]
#   }
# ]
# 2025-09-16 14:55:18.127 | INFO     | story_writer.workflow.planning_builder:build_plan:190 - Decomposing event: E2(2/6)
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# Full Event Graph (for high-level context):
# {
#   "nodes": [
#     {
#       "event_id": "E1",
#       "title": "Campsite Under Moonlight",
#       "summary": "The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.",
#       "time": "Nightfall",
#       "location": "Rocky mountain pass",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "weary but alert"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "injured but loyal"
#         }
#       ],
#       "goal": "Rest and assess their next move",
#       "conflict": "Discovering evidence of betrayal within their ranks",
#       "novelty_score": 0.7,
#       "coherence_score": 0.95
#     },
#     {
#       "event_id": "E2",
#       "title": "Whispers in the Snow",
#       "summary": "While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.",
#       "time": "Midnight",
#       "location": "High ridge near camp",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "tense and suspicious"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "asleep, vulnerable"
#         }
#       ],
#       "goal": "Identify the source of the mysterious signals",
#       "conflict": "Paranoia and the threat of ambush by former allies",
#       "novelty_score": 0.8,
#       "coherence_score": 0.9
#     },
#     {
#       "event_id": "E3",
#       "title": "Blood Trail at Dawn",
#       "summary": "At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.",
#       "time": "Dawn",
#       "location": "Frozen ravine",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "determined and vengeful"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "weakening from injury"
#         },
#         {
#           "name": "Dying Scout",
#           "role": "messenger",
#           "state": "near death"
#         }
#       ],
#       "goal": "Uncover the truth behind the betrayal",
#       "conflict": "Race against time to survive and expose the traitor",
#       "novelty_score": 0.85,
#       "coherence_score": 0.92
#     },
#     {
#       "event_id": "E4",
#       "title": "Ambush at the Pass",
#       "summary": "As Garrick and Tarn attempt to escape the mountains with the incriminating message, they are ambushed by a covert squad led by the traitor's loyal enforcer. A brutal firefight ensues in the narrow ice gorge.",
#       "time": "Morning",
#       "location": "Ice-covered mountain pass",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "battle-hardened and desperate"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "gravely wounded but fighting"
#         },
#         {
#           "name": "Kael",
#           "role": "antagonist's enforcer",
#           "state": "ruthless and efficient"
#         }
#       ],
#       "goal": "Survive the ambush and deliver the message to loyal forces",
#       "conflict": "Direct confrontation with the traitor's forces before the truth can be exposed",
#       "novelty_score": 0.75,
#       "coherence_score": 0.93
#     },
#     {
#       "event_id": "E5",
#       "title": "Final Stand at the Beacon",
#       "summary": "Cornered at an old signal tower, Garrick uses the last of their supplies to ignite a flare, revealing both their location and the traitor's name to a distant allied outpost. Tarn sacrifices himself to hold off the attackers.",
#       "time": "Late Morning",
#       "location": "Abandoned signal tower",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "grieving but resolute"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "sacrificial, heroic"
#         },
#         {
#           "name": "Kael",
#           "role": "antagonist's enforcer",
#           "state": "overpowered by resolve"
#         }
#       ],
#       "goal": "Transmit the truth despite overwhelming odds",
#       "conflict": "Moral and physical sacrifice versus institutional betrayal",
#       "novelty_score": 0.88,
#       "coherence_score": 0.96
#     },
#     {
#       "event_id": "E6",
#       "title": "Echoes in the Hall of Records",
#       "summary": "Weeks later, Garrick stands before a military tribunal, presenting the recovered evidence. The high-ranking officer is arrested, and a formal pardon is issued for Garrick and Tarn's unit. Garrick leaves, haunted but free.",
#       "time": "One month later",
#       "location": "Capital city war council chamber",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "weary, vindicated, solitary"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "deceased, remembered"
#         },
#         {
#           "name": "High-Ranking Officer",
#           "role": "traitor",
#           "state": "arrested and disgraced"
#         }
#       ],
#       "goal": "Secure justice for the betrayed unit",
#       "conflict": "Confronting systemic corruption with irrefutable proof",
#       "novelty_score": 0.7,
#       "coherence_score": 0.94
#     }
#   ],
#   "edges": [
#     {
#       "type": "causal",
#       "source_event_id": "E1",
#       "target_event_id": "E2",
#       "rationale": "The discovery of the battalion insignia in E1 heightens Garrick's suspicion, making him more alert and attuned to anomalies during watch, which leads to his detection of coded whispers in E2."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E1",
#       "target_event_id": "E2",
#       "rationale": "E1 occurs at nightfall and sets up the campsite; E2 takes place at midnight, representing a direct chronological progression in the same location vicinity."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E2",
#       "target_event_id": "E3",
#       "rationale": "Garrick’s suspicion from overhearing coded phrases in E2 motivates the pair to remain vigilant and investigate their surroundings at dawn, leading them to discover the blood trail and dying scout in E3."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E2",
#       "target_event_id": "E3",
#       "rationale": "E2 occurs at midnight, followed by E3 at dawn, maintaining a natural time sequence as the night transitions into morning."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E3",
#       "target_event_id": "E4",
#       "rationale": "The incriminating message obtained from the dying scout in E3 reveals the identity of the traitor, prompting Garrick and Tarn to flee with the evidence—directly triggering the ambush by the traitor's forces in E4."
#     },
#     {
#       "type": "thematic",
#       "source_event_id": "E3",
#       "target_event_id": "E5",
#       "rationale": "Both events center on revealing the truth despite personal cost: E3 uncovers the betrayal through a dying messenger, while E5 culminates in transmitting that truth through sacrifice."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E4",
#       "target_event_id": "E5",
#       "rationale": "The ambush in E4 forces Garrick and Tarn into retreat, cornering them at the abandoned signal tower where they make their final stand in E5."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E4",
#       "target_event_id": "E5",
#       "rationale": "E4 takes place in the morning and directly precedes E5 in late morning, showing continuous escalation within a single day."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E5",
#       "target_event_id": "E6",
#       "rationale": "The flare launched in E5 successfully alerts allied forces, enabling Garrick to later present the evidence at the tribunal in E6, resulting in the traitor's arrest."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E5",
#       "target_event_id": "E6",
#       "rationale": "E5 concludes with the signal being sent; E6 occurs one month later, representing the delayed but logical aftermath of that transmission."
#     },
#     {
#       "type": "thematic",
#       "source_event_id": "E1",
#       "target_event_id": "E6",
#       "rationale": "Both events bookend the arc of betrayal and justice: E1 introduces the theme of internal treachery, while E6 resolves it through institutional accountability."
#     },
#     {
#       "type": "thematic",
#       "source_event_id": "E4",
#       "target_event_id": "E6",
#       "rationale": "E4 represents the peak of physical conflict against the traitor’s enforcers, while E6 represents the peak of moral and systemic confrontation—both are pivotal moments in opposing the corruption introduced earlier."
#     }
#   ]
# }
#
# TargetEventID (to expand):
# E2
#
# Requirements:
# - Generate 3-5 sub-events.
# - Focus on richness and interweave potential (e.g., setups for future events).
#
# ---------- TextMessage (subtasker_agent) ----------
# [
#   {
#     "sub_event_id": "E2_S1",
#     "parent_event_id": "E2",
#     "title": "The Watch Begins",
#     "summary": "Garrick takes the midnight watch, wrapping himself in a frost-stiffened cloak as he scans the snow-blanketed ridge. The wind howls through narrow fissures in the rock, creating an eerie chorus that masks all but the most deliberate sounds. He checks Tarn’s bandages and finds the wound seeping again—concern gnaws at him, sharpening his senses. A faint crunch, almost swallowed by the wind, makes him turn. Nothing moves. Yet the air feels watched.",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "tense and suspicious"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "asleep, vulnerable"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E2_S2",
#     "parent_event_id": "E2",
#     "title": "Whispers in the Static",
#     "summary": "As a gust funnels through a limestone chimney above camp, it produces a low, rhythmic moan. Garrick nearly dismisses it—until he catches a fragmented phrase: '...vector nine... secure the pass...'—the cadence unmistakably matching the unit’s encrypted field code. He freezes, breath clouding in sharp bursts. He listens for minutes more. Another burst: '...target still alive...' The words vanish with the wind, leaving doubt—is it nature, hallucination, or hunters closing in?",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "tense and suspicious"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "asleep, vulnerable"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E2_S3",
#     "parent_event_id": "E2",
#     "title": "False Alarm and Hidden Mark",
#     "summary": "Convinced of enemy presence, Garrick readies his rifle and creeps toward the ridge’s edge. He spots a dark shape shifting in the mist—only to realize it’s a tattered banner, half-buried in snow, bearing the insignia of their own battalion. He retrieves it, pulse racing. Scratched into the metal clasp: a series of tally marks and the letter 'K'. He recalls Kael, the captain’s enforcer, rarely seen at camp. Was this planted? A warning? Or a trap?",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "tense and suspicious"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E2_S4",
#     "parent_event_id": "E2",
#     "title": "Silent Decision",
#     "summary": "Returning to camp, Garrick hesitates to wake Tarn. The injury slows him, and panic could worsen it. Instead, he quietly packs their most vital supplies into a smaller satchel, prepping for a rapid escape. He hides a spare pistol beneath a rock near the trailhead, marking it with a subtle scratch—just in case they’re separated. He stares into the dark pass, now seeing not just terrain, but a net tightening around them.",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "tense and suspicious"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "asleep, vulnerable"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E2_S5",
#     "parent_event_id": "E2",
#     "title": "Echo Response",
#     "summary": "Testing his theory, Garrick uses a broken signal mirror to flash a brief, coded pulse toward the ridge—'status check' in battalion hand-signal shorthand. Minutes pass. Then, a flicker answers from a distant outcrop: three quick flashes. Not wind. Not chance. They are not alone. And worse—they are recognized.",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "tense and suspicious"
#       }
#     ]
#   }
# ]
# 2025-09-16 14:55:45.331 | INFO     | story_writer.workflow.planning_builder:build_plan:190 - Decomposing event: E3(3/6)
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# Full Event Graph (for high-level context):
# {
#   "nodes": [
#     {
#       "event_id": "E1",
#       "title": "Campsite Under Moonlight",
#       "summary": "The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.",
#       "time": "Nightfall",
#       "location": "Rocky mountain pass",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "weary but alert"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "injured but loyal"
#         }
#       ],
#       "goal": "Rest and assess their next move",
#       "conflict": "Discovering evidence of betrayal within their ranks",
#       "novelty_score": 0.7,
#       "coherence_score": 0.95
#     },
#     {
#       "event_id": "E2",
#       "title": "Whispers in the Snow",
#       "summary": "While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.",
#       "time": "Midnight",
#       "location": "High ridge near camp",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "tense and suspicious"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "asleep, vulnerable"
#         }
#       ],
#       "goal": "Identify the source of the mysterious signals",
#       "conflict": "Paranoia and the threat of ambush by former allies",
#       "novelty_score": 0.8,
#       "coherence_score": 0.9
#     },
#     {
#       "event_id": "E3",
#       "title": "Blood Trail at Dawn",
#       "summary": "At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.",
#       "time": "Dawn",
#       "location": "Frozen ravine",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "determined and vengeful"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "weakening from injury"
#         },
#         {
#           "name": "Dying Scout",
#           "role": "messenger",
#           "state": "near death"
#         }
#       ],
#       "goal": "Uncover the truth behind the betrayal",
#       "conflict": "Race against time to survive and expose the traitor",
#       "novelty_score": 0.85,
#       "coherence_score": 0.92
#     },
#     {
#       "event_id": "E4",
#       "title": "Ambush at the Pass",
#       "summary": "As Garrick and Tarn attempt to escape the mountains with the incriminating message, they are ambushed by a covert squad led by the traitor's loyal enforcer. A brutal firefight ensues in the narrow ice gorge.",
#       "time": "Morning",
#       "location": "Ice-covered mountain pass",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "battle-hardened and desperate"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "gravely wounded but fighting"
#         },
#         {
#           "name": "Kael",
#           "role": "antagonist's enforcer",
#           "state": "ruthless and efficient"
#         }
#       ],
#       "goal": "Survive the ambush and deliver the message to loyal forces",
#       "conflict": "Direct confrontation with the traitor's forces before the truth can be exposed",
#       "novelty_score": 0.75,
#       "coherence_score": 0.93
#     },
#     {
#       "event_id": "E5",
#       "title": "Final Stand at the Beacon",
#       "summary": "Cornered at an old signal tower, Garrick uses the last of their supplies to ignite a flare, revealing both their location and the traitor's name to a distant allied outpost. Tarn sacrifices himself to hold off the attackers.",
#       "time": "Late Morning",
#       "location": "Abandoned signal tower",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "grieving but resolute"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "sacrificial, heroic"
#         },
#         {
#           "name": "Kael",
#           "role": "antagonist's enforcer",
#           "state": "overpowered by resolve"
#         }
#       ],
#       "goal": "Transmit the truth despite overwhelming odds",
#       "conflict": "Moral and physical sacrifice versus institutional betrayal",
#       "novelty_score": 0.88,
#       "coherence_score": 0.96
#     },
#     {
#       "event_id": "E6",
#       "title": "Echoes in the Hall of Records",
#       "summary": "Weeks later, Garrick stands before a military tribunal, presenting the recovered evidence. The high-ranking officer is arrested, and a formal pardon is issued for Garrick and Tarn's unit. Garrick leaves, haunted but free.",
#       "time": "One month later",
#       "location": "Capital city war council chamber",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "weary, vindicated, solitary"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "deceased, remembered"
#         },
#         {
#           "name": "High-Ranking Officer",
#           "role": "traitor",
#           "state": "arrested and disgraced"
#         }
#       ],
#       "goal": "Secure justice for the betrayed unit",
#       "conflict": "Confronting systemic corruption with irrefutable proof",
#       "novelty_score": 0.7,
#       "coherence_score": 0.94
#     }
#   ],
#   "edges": [
#     {
#       "type": "causal",
#       "source_event_id": "E1",
#       "target_event_id": "E2",
#       "rationale": "The discovery of the battalion insignia in E1 heightens Garrick's suspicion, making him more alert and attuned to anomalies during watch, which leads to his detection of coded whispers in E2."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E1",
#       "target_event_id": "E2",
#       "rationale": "E1 occurs at nightfall and sets up the campsite; E2 takes place at midnight, representing a direct chronological progression in the same location vicinity."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E2",
#       "target_event_id": "E3",
#       "rationale": "Garrick’s suspicion from overhearing coded phrases in E2 motivates the pair to remain vigilant and investigate their surroundings at dawn, leading them to discover the blood trail and dying scout in E3."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E2",
#       "target_event_id": "E3",
#       "rationale": "E2 occurs at midnight, followed by E3 at dawn, maintaining a natural time sequence as the night transitions into morning."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E3",
#       "target_event_id": "E4",
#       "rationale": "The incriminating message obtained from the dying scout in E3 reveals the identity of the traitor, prompting Garrick and Tarn to flee with the evidence—directly triggering the ambush by the traitor's forces in E4."
#     },
#     {
#       "type": "thematic",
#       "source_event_id": "E3",
#       "target_event_id": "E5",
#       "rationale": "Both events center on revealing the truth despite personal cost: E3 uncovers the betrayal through a dying messenger, while E5 culminates in transmitting that truth through sacrifice."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E4",
#       "target_event_id": "E5",
#       "rationale": "The ambush in E4 forces Garrick and Tarn into retreat, cornering them at the abandoned signal tower where they make their final stand in E5."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E4",
#       "target_event_id": "E5",
#       "rationale": "E4 takes place in the morning and directly precedes E5 in late morning, showing continuous escalation within a single day."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E5",
#       "target_event_id": "E6",
#       "rationale": "The flare launched in E5 successfully alerts allied forces, enabling Garrick to later present the evidence at the tribunal in E6, resulting in the traitor's arrest."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E5",
#       "target_event_id": "E6",
#       "rationale": "E5 concludes with the signal being sent; E6 occurs one month later, representing the delayed but logical aftermath of that transmission."
#     },
#     {
#       "type": "thematic",
#       "source_event_id": "E1",
#       "target_event_id": "E6",
#       "rationale": "Both events bookend the arc of betrayal and justice: E1 introduces the theme of internal treachery, while E6 resolves it through institutional accountability."
#     },
#     {
#       "type": "thematic",
#       "source_event_id": "E4",
#       "target_event_id": "E6",
#       "rationale": "E4 represents the peak of physical conflict against the traitor’s enforcers, while E6 represents the peak of moral and systemic confrontation—both are pivotal moments in opposing the corruption introduced earlier."
#     }
#   ]
# }
#
# TargetEventID (to expand):
# E3
#
# Requirements:
# - Generate 3-5 sub-events.
# - Focus on richness and interweave potential (e.g., setups for future events).
#
# ---------- TextMessage (subtasker_agent) ----------
# [
#   {
#     "sub_event_id": "E3_S1",
#     "parent_event_id": "E3",
#     "title": "Frostbitten Trail",
#     "summary": "At first light, Garrick and Tarn spot a faint smear of blood on the ice near their camp—quickly fading in the rising wind. Tarn insists it's worth following despite his worsening injury, suspecting it might be one of their missing scouts. Garrick reluctantly agrees, marking their path with broken arrowheads to avoid getting lost in the whiteout.",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "cautious and burdened"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "weakening but insistent"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E3_S2",
#     "parent_event_id": "E3",
#     "title": "Whispers Beneath Ice",
#     "summary": "The trail leads into a narrow fissure in the ravine wall, half-hidden by frozen mist. Inside, they hear shallow breathing beneath a thin crust of ice. Garrick breaks through with his blade, revealing a half-buried scout from their unit, his leg trapped and body numb. The man clutches a sealed oilskin pouch against his chest.",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "shocked and urgent"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "exhausted but focused"
#       },
#       {
#         "name": "Dying Scout",
#         "role": "messenger",
#         "state": "frozen and delirious"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E3_S3",
#     "parent_event_id": "E3",
#     "title": "Last Words in Code",
#     "summary": "The scout regains brief lucidity and speaks in fragmented officer cipher—naming 'Commander Veyne' as the one who ordered the ambush and burned the rear guard. With his final strength, he presses the oilskin pouch into Tarn’s hand, whispering 'Burn it if you're followed.' His eyes glaze over before he can say more.",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "horrified and enraged"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "solemn and resolute"
#       },
#       {
#         "name": "Dying Scout",
#         "role": "messenger",
#         "state": "deceased"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E3_S4",
#     "parent_event_id": "E3",
#     "title": "Signs of Pursuit",
#     "summary": "As they exit the crevice, Garrick notices fresh boot prints in the snow—too large to be the scout’s, and aligned with military spacing. He finds a snapped wire tap hidden in the rocks nearby, confirming surveillance. They realize the enemy knows they have the message and may already be moving to intercept.",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "hyper-vigilant and calculating"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "pained but alert"
#       }
#     ]
#   },
#   {
#     "sub_event_id": "E3_S5",
#     "parent_event_id": "E3",
#     "title": "Decision at the Divide",
#     "summary": "Facing two paths—one steep but concealed, the other wide and fast but exposed—Garrick and Tarn argue over their route. Tarn insists on speed to deliver the message, while Garrick fears a trap. They ultimately choose the narrow ridge, unaware that Kael’s ambush team is already converging on the high pass ahead.",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "torn between caution and urgency"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "determined despite pain"
#       }
#     ]
#   }
# ]
# 2025-09-16 14:56:13.052 | INFO     | story_writer.workflow.planning_builder:build_plan:190 - Decomposing event: E4(4/6)
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# Full Event Graph (for high-level context):
# {
#   "nodes": [
#     {
#       "event_id": "E1",
#       "title": "Campsite Under Moonlight",
#       "summary": "The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.",
#       "time": "Nightfall",
#       "location": "Rocky mountain pass",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "weary but alert"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "injured but loyal"
#         }
#       ],
#       "goal": "Rest and assess their next move",
#       "conflict": "Discovering evidence of betrayal within their ranks",
#       "novelty_score": 0.7,
#       "coherence_score": 0.95
#     },
#     {
#       "event_id": "E2",
#       "title": "Whispers in the Snow",
#       "summary": "While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.",
#       "time": "Midnight",
#       "location": "High ridge near camp",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "tense and suspicious"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "asleep, vulnerable"
#         }
#       ],
#       "goal": "Identify the source of the mysterious signals",
#       "conflict": "Paranoia and the threat of ambush by former allies",
#       "novelty_score": 0.8,
#       "coherence_score": 0.9
#     },
#     {
#       "event_id": "E3",
#       "title": "Blood Trail at Dawn",
#       "summary": "At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.",
#       "time": "Dawn",
#       "location": "Frozen ravine",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "determined and vengeful"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "weakening from injury"
#         },
#         {
#           "name": "Dying Scout",
#           "role": "messenger",
#           "state": "near death"
#         }
#       ],
#       "goal": "Uncover the truth behind the betrayal",
#       "conflict": "Race against time to survive and expose the traitor",
#       "novelty_score": 0.85,
#       "coherence_score": 0.92
#     },
#     {
#       "event_id": "E4",
#       "title": "Ambush at the Pass",
#       "summary": "As Garrick and Tarn attempt to escape the mountains with the incriminating message, they are ambushed by a covert squad led by the traitor's loyal enforcer. A brutal firefight ensues in the narrow ice gorge.",
#       "time": "Morning",
#       "location": "Ice-covered mountain pass",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "battle-hardened and desperate"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "gravely wounded but fighting"
#         },
#         {
#           "name": "Kael",
#           "role": "antagonist's enforcer",
#           "state": "ruthless and efficient"
#         }
#       ],
#       "goal": "Survive the ambush and deliver the message to loyal forces",
#       "conflict": "Direct confrontation with the traitor's forces before the truth can be exposed",
#       "novelty_score": 0.75,
#       "coherence_score": 0.93
#     },
#     {
#       "event_id": "E5",
#       "title": "Final Stand at the Beacon",
#       "summary": "Cornered at an old signal tower, Garrick uses the last of their supplies to ignite a flare, revealing both their location and the traitor's name to a distant allied outpost. Tarn sacrifices himself to hold off the attackers.",
#       "time": "Late Morning",
#       "location": "Abandoned signal tower",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "grieving but resolute"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "sacrificial, heroic"
#         },
#         {
#           "name": "Kael",
#           "role": "antagonist's enforcer",
#           "state": "overpowered by resolve"
#         }
#       ],
#       "goal": "Transmit the truth despite overwhelming odds",
#       "conflict": "Moral and physical sacrifice versus institutional betrayal",
#       "novelty_score": 0.88,
#       "coherence_score": 0.96
#     },
#     {
#       "event_id": "E6",
#       "title": "Echoes in the Hall of Records",
#       "summary": "Weeks later, Garrick stands before a military tribunal, presenting the recovered evidence. The high-ranking officer is arrested, and a formal pardon is issued for Garrick and Tarn's unit. Garrick leaves, haunted but free.",
#       "time": "One month later",
#       "location": "Capital city war council chamber",
#       "characters": [
#         {
#           "name": "Garrick",
#           "role": "protagonist",
#           "state": "weary, vindicated, solitary"
#         },
#         {
#           "name": "Tarn",
#           "role": "comrade",
#           "state": "deceased, remembered"
#         },
#         {
#           "name": "High-Ranking Officer",
#           "role": "traitor",
#           "state": "arrested and disgraced"
#         }
#       ],
#       "goal": "Secure justice for the betrayed unit",
#       "conflict": "Confronting systemic corruption with irrefutable proof",
#       "novelty_score": 0.7,
#       "coherence_score": 0.94
#     }
#   ],
#   "edges": [
#     {
#       "type": "causal",
#       "source_event_id": "E1",
#       "target_event_id": "E2",
#       "rationale": "The discovery of the battalion insignia in E1 heightens Garrick's suspicion, making him more alert and attuned to anomalies during watch, which leads to his detection of coded whispers in E2."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E1",
#       "target_event_id": "E2",
#       "rationale": "E1 occurs at nightfall and sets up the campsite; E2 takes place at midnight, representing a direct chronological progression in the same location vicinity."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E2",
#       "target_event_id": "E3",
#       "rationale": "Garrick’s suspicion from overhearing coded phrases in E2 motivates the pair to remain vigilant and investigate their surroundings at dawn, leading them to discover the blood trail and dying scout in E3."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E2",
#       "target_event_id": "E3",
#       "rationale": "E2 occurs at midnight, followed by E3 at dawn, maintaining a natural time sequence as the night transitions into morning."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E3",
#       "target_event_id": "E4",
#       "rationale": "The incriminating message obtained from the dying scout in E3 reveals the identity of the traitor, prompting Garrick and Tarn to flee with the evidence—directly triggering the ambush by the traitor's forces in E4."
#     },
#     {
#       "type": "thematic",
#       "source_event_id": "E3",
#       "target_event_id": "E5",
#       "rationale": "Both events center on revealing the truth despite personal cost: E3 uncovers the betrayal through a dying messenger, while E5 culminates in transmitting that truth through sacrifice."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E4",
#       "target_event_id": "E5",
#       "rationale": "The ambush in E4 forces Garrick and Tarn into retreat, cornering them at the abandoned signal tower where they make their final stand in E5."
#     },
#     {
#       "type": "temporal",
#       "source_event_id": "E4",
#       "target_event_id": "E5",
#       "rationale": "E4 takes place in the morning and directly precedes E5 in late morning, showing continuous escalation within a single day."
#     },
#     {
#       "type": "causal",
#       "source_event_id": "E5",
#       "target_event_id": "E6",
# ...
# {"sub_event_id":"E3_S3","parent_event_id":"E3","title":"Last Words in Code","summary":"The scout regains brief lucidity and speaks in fragmented officer cipher—naming 'Commander Veyne' as the one who ordered the ambush and burned the rear guard. With his final strength, he presses the oilskin pouch into Tarn’s hand, whispering 'Burn it if you're followed.' His eyes glaze over before he can say more.","characters":[{"name":"Garrick","role":"protagonist","state":"horrified and enraged"},{"name":"Tarn","role":"comrade","state":"solemn and resolute"},{"name":"Dying Scout","role":"messenger","state":"deceased"}]}
# {"sub_event_id":"E3_S4","parent_event_id":"E3","title":"Signs of Pursuit","summary":"As they exit the crevice, Garrick notices fresh boot prints in the snow—too large to be the scout’s, and aligned with military spacing. He finds a snapped wire tap hidden in the rocks nearby, confirming surveillance. They realize the enemy knows they have the message and may already be moving to intercept.","characters":[{"name":"Garrick","role":"protagonist","state":"hyper-vigilant and calculating"},{"name":"Tarn","role":"comrade","state":"pained but alert"}]}
# {"sub_event_id":"E3_S5","parent_event_id":"E3","title":"Decision at the Divide","summary":"Facing two paths—one steep but concealed, the other wide and fast but exposed—Garrick and Tarn argue over their route. Tarn insists on speed to deliver the message, while Garrick fears a trap. They ultimately choose the narrow ridge, unaware that Kael’s ambush team is already converging on the high pass ahead.","characters":[{"name":"Garrick","role":"protagonist","state":"torn between caution and urgency"},{"name":"Tarn","role":"comrade","state":"determined despite pain"}]}
# {"sub_event_id":"E4_S1","parent_event_id":"E4","title":"The Ice Gorge Approach","summary":"Garrick and Tarn navigate a narrow ice gorge, their breath fogging in the frigid air. Garrick notices disturbed snow patterns—recent footprints veering off the main path, too many for a patrol. He signals Tarn to move quietly, suspecting an ambush. Tarn stumbles, his wound reopening, leaving a faint smear of blood on the ice—a trail they can’t afford.","characters":[{"name":"Garrick","role":"protagonist","state":"battle-hardened and desperate"},{"name":"Tarn","role":"comrade","state":"gravely wounded but fighting"}]}
# {"sub_event_id":"E4_S2","parent_event_id":"E4","title":"First Shot, Frozen Echo","summary":"A sniper’s bullet cracks through the silence, shattering ice above Garrick’s head. The shot was deliberate—meant to miss. It’s a signal. From concealed positions along the ridge, Kael’s squad opens fire with controlled bursts, herding the two toward a dead-end crevasse. Garrick drags Tarn behind a frozen boulder, realizing the ambush was planned around their escape route—not chance.","characters":[{"name":"Garrick","role":"protagonist","state":"battle-hardened and desperate"},{"name":"Tarn","role":"comrade","state":"gravely wounded but fighting"},{"name":"Kael","role":"antagonist's enforcer","state":"ruthless and efficient"}]}
# {"sub_event_id":"E4_S3","parent_event_id":"E4","title":"Tarn’s Last Stand at the Chasm","summary":"Cornered at the chasm’s edge, Tarn pushes Garrick toward a narrow ledge beneath the ice wall, shouting that he’ll hold them off. Using the last of his strength, he triggers a small avalanche with a well-placed grenade, collapsing the central path and forcing Kael’s men to regroup. As Kael emerges alone, cold fury in his eyes, Tarn raises his sidearm—one round left.","characters":[{"name":"Garrick","role":"protagonist","state":"battle-hardened and desperate"},{"name":"Tarn","role":"comrade","state":"gravely wounded but fighting"},{"name":"Kael","role":"antagonist's enforcer","state":"ruthless and efficient"}]}
# {"sub_event_id":"E4_S4","parent_event_id":"E4","title":"Message in the Snow","summary":"As Garrick crawls beneath the ice shelf, he presses the incriminating message into a waterproof capsule and lodges it deep in a glacial fissure, marking it with Tarn’s dog tag. If he doesn’t make it, someone might still find it. Above, gunfire ceases. Silence. Then Kael’s voice echoes: 'You don’t have to die for a lie, Garrick.' The words plant a seed of doubt—was the message forged?","characters":[{"name":"Garrick","role":"protagonist","state":"battle-hardened and desperate"},{"name":"Kael","role":"antagonist's enforcer","state":"ruthless and efficient"}]}
# {"sub_event_id":"E4_S5","parent_event_id":"E4","title":"The Flare Path Revealed","summary":"Garrick escapes the gorge and spots the distant silhouette of the abandoned signal tower on the ridge. A memory flashes—Tarn once mentioned it during training: 'Old beacon, one flare charge left. Lights up half the valley.' Hope ignites. He clutches the detonator in his pocket, vowing to send the truth skyward—even if it costs everything.","characters":[{"name":"Garrick","role":"protagonist","state":"grieving but resolute"},{"name":"Tarn","role":"comrade","state":"sacrificial, heroic"}]}
# {"sub_event_id":"E5_S1","parent_event_id":"E5","title":"The Last Ammunition Inventory","summary":"As the sound of approaching boots echoes through the icy canyon, Garrick and Tarn retreat to the crumbling signal tower. With grim urgency, they take stock of their dwindling supplies—only three rounds left for Garrick’s rifle, a half-empty magazine for Tarn’s sidearm, and a single emergency flare. Tarn hides the incriminating message inside his coat, stitching it into the lining with frozen fingers. He insists Garrick promise to fire the flare even if he falls.","characters":[{"name":"Garrick","role":"protagonist","state":"desperate but focused"},{"name":"Tarn","role":"comrade","state":"gravely wounded, determined"}]}
# {"sub_event_id":"E5_S2","parent_event_id":"E5","title":"Kael’s Voice from the Wind","summary":"From the ridge above, Kael uses a stolen command frequency to broadcast a distorted voice recording of the high-ranking officer ordering Garrick and Tarn’s execution ‘for desertion.’ The ploy is meant to sow doubt and delay their final act. Tarn nearly hesitates, questioning if the betrayal was ever real—but Garrick smashes the radio, shouting that the officer’s voice lacks its telltale stutter, a detail only inner-circle troops would know.","characters":[{"name":"Garrick","role":"protagonist","state":"furious and resolute"},{"name":"Tarn","role":"comrade","state":"doubtful, then resolved"},{"name":"Kael","role":"antagonist's enforcer","state":"manipulative and in control"}]}
# {"sub_event_id":"E5_S3","parent_event_id":"E5","title":"Tarn’s Final Stand at the Gate","summary":"As enemy forces close in, Tarn drags himself to the tower’s rusted entrance, propping a shattered beam against the door. When the enforcers breach the gate, he triggers a makeshift avalanche by shooting weakened ice columns overhead, burying two attackers and buying Garrick critical seconds. Mortally wounded by return fire, Tarn collapses, whispering the unit’s motto—‘Truth outlives blood’—before going still.","characters":[{"name":"Tarn","role":"comrade","state":"sacrificial, heroic"},{"name":"Garrick","role":"protagonist","state":"grief-stricken but driven"},{"name":"Kael","role":"antagonist's enforcer","state":"ruthless, momentarily thwarted"}]}
# {"sub_event_id":"E5_S4","parent_event_id":"E5","title":"Ignition of the Beacon","summary":"Alone and bleeding, Garrick climbs the tower’s unstable gantry. He primes the old flare mechanism, inscribing the traitor’s name and coordinates onto the canister with his knife. As Kael reaches the base, Garrick fires the flare—it streaks skyward in a blinding arc, visible for miles. The signal pulses not just location, but a coded distress tag known only to loyal intelligence cells, ensuring the message will be authenticated.","characters":[{"name":"Garrick","role":"protagonist","state":"resolute, transcendent"},{"name":"Kael","role":"antagonist's enforcer","state":"defeated in purpose"}]}
# {"sub_event_id":"E5_S5","parent_event_id":"E5","title":"Echoes Across the Range","summary":"The flare detonates high above, casting red light across the snow. In distant valleys, hidden watchers—a rogue scout, a defecting courier, and an old signals operator—see the burst and recognize the unique signature. One activates a dormant relay; another begins transcribing the code. Unseen, the truth starts spreading beyond military channels, seeding future resistance.","characters":[{"name":"Garrick","role":"protagonist","state":"vindicated, isolated"},{"name":"Rogue Scout","role":"future ally","state":"awakened"},{"name":"Defecting Courier","role":"future informant","state":"decisive"},{"name":"Signals Operator","role":"future contact","state":"alert and ready"}]}
# {"sub_event_id":"E6_S1","parent_event_id":"E6","title":"The Weight of Silence Before Testimony","summary":"Minutes before the tribunal convenes, Garrick stands alone in a dim antechamber beneath the war council hall. A junior clerk, trembling, hands him a sealed envelope—left behind by Tarn during their last supply run—containing personal letters and a hidden ledger page with encrypted financial transfers implicating other officers. The revelation forces Garrick to consider whether justice can be contained within one trial.","characters":[{"name":"Garrick","role":"protagonist","state":"solemn and burdened"},{"name":"Junior Clerk","role":"messenger","state":"nervous but resolute"}]}
# {"sub_event_id":"E6_S2","parent_event_id":"E6","title":"Tarn's Final Words Read Aloud","summary":"At the start of the tribunal, Garrick requests permission to read Tarn’s final letter—not just as evidence, but as testimony. As he reads aloud Tarn’s reflections on loyalty, duty, and the cost of silence, several officers in attendance shift uncomfortably, including a previously neutral adjutant who later discreetly signals willingness to cooperate with further investigations.","characters":[{"name":"Garrick","role":"protagonist","state":"grieving but composed"},{"name":"Tarn","role":"comrade","state":"deceased, remembered"},{"name":"Council Members","role":"authority figures","state":"divided in reaction"}]}
# {"sub_event_id":"E6_S3","parent_event_id":"E6","title":"The Traitor’s Defiance","summary":"When confronted with the incriminating message recovered from the dying scout, the high-ranking officer does not deny his actions but instead argues that the campaign’s failure necessitated sacrifice—and that men like Garrick were always expendable. His cold logic stirs murmurs among the council, exposing deep ideological fractures within the military leadership.","characters":[{"name":"Garrick","role":"protagonist","state":"outraged but restrained"},{"name":"High-Ranking Officer","role":"traitor","state":"defiant and unrepentant"},{"name":"Military Tribunal Panel","role":"judges","state":"unsettled and divided"}]}
# {"sub_event_id":"E6_S4","parent_event_id":"E6","title":"Pardon Amidst Shadows","summary":"The tribunal issues a formal pardon for Garrick and Tarn’s unit, publicly clearing their names. However, as records are updated, an unseen archivist makes a coded notation in the margins—marking Garrick’s file with a black sigil used for 'potential destabilizers.' This quiet act hints at ongoing surveillance and future targeting despite official vindication.","characters":[{"name":"Garrick","role":"protagonist","state":"vindicated but uneasy"},{"name":"Archivist","role":"background observer","state":"covert and methodical"},{"name":"Tarn","role":"comrade","state":"honored posthumously"}]}
# {"sub_event_id":"E6_S5","parent_event_id":"E6","title":"A Letter Sent Into the Wild","summary":"After leaving the chamber, Garrick does not return to barracks. Instead, he writes a short, unsanctioned letter addressed to surviving members of scattered loyalist cells—using cipher patterns known only to trusted operatives. He hides it inside a departing courier pigeon’s capsule, setting in motion a clandestine network that may one day resist deeper corruption.","characters":[{"name":"Garrick","role":"protagonist","state":"solitary and purposeful"}]}
#
# Task:
# Analyze the premise, the event graph, and all sub-events. Then, construct the final **array of JSON objects** by assigning all sub-events into a sequence of chapters. Use non-linear techniques where appropriate to make the story more engaging.
#
# ---------- TextMessage (weaver_agent) ----------
# [
#   {
#     "chapter_id": 1,
#     "title": "The Weight of Ash and Silence",
#     "summary": "A nonlinear opening that begins in medias res with Garrick preparing for the tribunal, then flashes back to the quiet horror of the mountain camp. The chapter weaves early signs of betrayal—disturbed earth, a hidden insignia, burned orders—with the emotional weight of loyalty and doubt, establishing the psychological toll of war and deception.",
#     "sub_event_ids": [
#       "E6_S1",
#       "E1_S1",
#       "E1_S2",
#       "E1_S3",
#       "E1_S5",
#       "E1_S4"
#     ]
#   },
#   {
#     "chapter_id": 2,
#     "title": "Voices in the Wind, Marks in the Snow",
#     "summary": "Told almost entirely in real-time from Garrick’s midnight watch, this chapter builds paranoia through fragmented whispers, ambiguous signals, and subtle traps. Flash-forwards are embedded as fleeting memories—Garrick briefly hallucinates Tarn falling, the flare igniting—heightening tension as he deciphers whether the enemy is real or inside his mind.",
#     "sub_event_ids": [
#       "E2_S1",
#       "E2_S2",
#       "E2_S3",
#       "E2_S5",
#       "E2_S4"
#     ]
#   },
#   {
#     "chapter_id": 3,
#     "title": "Blood Beneath the Ice",
#     "summary": "A tightly paced chapter following the discovery of the dying scout and the incriminating message. Through sharp sensory details and rising urgency, it contrasts the fragility of truth with the brutality of pursuit, culminating in the fateful decision at the divide—where hope and doom converge.",
#     "sub_event_ids": [
#       "E3_S1",
#       "E3_S2",
#       "E3_S3",
#       "E3_S4",
#       "E3_S5"
#     ]
#   },
#   {
#     "chapter_id": 4,
#     "title": "The Ambush in Frozen Time",
#     "summary": "Presented with a fractured timeline, this chapter intercuts the ice gorge ambush with flashbacks triggered by each gunshot: Tarn’s laughter during training, the forged reroute order, Varek’s last transmission. The chaos of battle merges with memory, revealing how the past has weaponized the present.",
#     "sub_event_ids": [
#       "E4_S1",
#       "E1_S3",
#       "E4_S2",
#       "E3_S3",
#       "E4_S3",
#       "E4_S4",
#       "E4_S5"
#     ]
#   },
#   {
#     "chapter_id": 5,
#     "title": "Truth in Fire and Smoke",
#     "summary": "From the crumbling signal tower to the sky-rending flare, this chapter unfolds chronologically but deepens its impact with visions—Tarn alive, giving orders; Kael hesitating; the beacon lighting a rebellion across the range. The final stand becomes mythic, transcending survival to become legacy.",
#     "sub_event_ids": [
#       "E5_S1",
#       "E5_S2",
#       "E5_S3",
#       "E5_S4",
#       "E5_S5"
#     ]
#   },
#   {
#     "chapter_id": 6,
#     "title": "Echoes That Never Fade",
#     "summary": "The aftermath refracts justice through silence, bureaucracy, and quiet resistance. Rather than conclude with closure, this chapter uses the tribunal not as an end but a beginning—revealing deeper corruption, honoring Tarn’s voice, and launching a secret network that ensures the truth will outlive institutions.",
#     "sub_event_ids": [
#       "E6_S2",
#       "E6_S3",
#       "E6_S4",
#       "E6_S5",
#       "E5_S5"
#     ]
#   }
# ]
# 2025-09-16 14:58:15.180 | INFO     | story_writer.workflow.planning_builder:build_plan:207 - Generated 6 chapters

# %%
story_plan.model_dump()
# Out:
# {'event_graph': {'nodes': [{'event_id': 'E1',
#     'title': 'Campsite Under Moonlight',
#     'summary': 'The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.',
#     'time': 'Nightfall',
#     'location': 'Rocky mountain pass',
#     'characters': [{'name': 'Garrick',
#       'role': 'protagonist',
#       'state': 'weary but alert'},
#      {'name': 'Tarn', 'role': 'comrade', 'state': 'injured but loyal'}],
#     'goal': 'Rest and assess their next move',
#     'conflict': 'Discovering evidence of betrayal within their ranks',
#     'novelty_score': 0.7,
#     'coherence_score': 0.95},
#    {'event_id': 'E2',
#     'title': 'Whispers in the Snow',
#     'summary': 'While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.',
#     'time': 'Midnight',
#     'location': 'High ridge near camp',
#     'characters': [{'name': 'Garrick',
#       'role': 'protagonist',
#       'state': 'tense and suspicious'},
#      {'name': 'Tarn', 'role': 'comrade', 'state': 'asleep, vulnerable'}],
#     'goal': 'Identify the source of the mysterious signals',
#     'conflict': 'Paranoia and the threat of ambush by former allies',
#     'novelty_score': 0.8,
#     'coherence_score': 0.9},
#    {'event_id': 'E3',
#     'title': 'Blood Trail at Dawn',
#     'summary': 'At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.',
#     'time': 'Dawn',
#     'location': 'Frozen ravine',
#     'characters': [{'name': 'Garrick',
#       'role': 'protagonist',
#       'state': 'determined and vengeful'},
#      {'name': 'Tarn', 'role': 'comrade', 'state': 'weakening from injury'},
#      {'name': 'Dying Scout', 'role': 'messenger', 'state': 'near death'}],
#     'goal': 'Uncover the truth behind the betrayal',
#     'conflict': 'Race against time to survive and expose the traitor',
#     'novelty_score': 0.85,
#     'coherence_score': 0.92},
#    {'event_id': 'E4',
#     'title': 'Ambush at the Pass',
#     'summary': "As Garrick and Tarn attempt to escape the mountains with the incriminating message, they are ambushed by a covert squad led by the traitor's loyal enforcer. A brutal firefight ensues in the narrow ice gorge.",
#     'time': 'Morning',
#     'location': 'Ice-covered mountain pass',
#     'characters': [{'name': 'Garrick',
#       'role': 'protagonist',
#       'state': 'battle-hardened and desperate'},
#      {'name': 'Tarn',
#       'role': 'comrade',
#       'state': 'gravely wounded but fighting'},
#      {'name': 'Kael',
#       'role': "antagonist's enforcer",
#       'state': 'ruthless and efficient'}],
#     'goal': 'Survive the ambush and deliver the message to loyal forces',
#     'conflict': "Direct confrontation with the traitor's forces before the truth can be exposed",
#     'novelty_score': 0.75,
#     'coherence_score': 0.93},
#    {'event_id': 'E5',
#     'title': 'Final Stand at the Beacon',
#     'summary': "Cornered at an old signal tower, Garrick uses the last of their supplies to ignite a flare, revealing both their location and the traitor's name to a distant allied outpost. Tarn sacrifices himself to hold off the attackers.",
#     'time': 'Late Morning',
#     'location': 'Abandoned signal tower',
#     'characters': [{'name': 'Garrick',
#       'role': 'protagonist',
#       'state': 'grieving but resolute'},
#      {'name': 'Tarn', 'role': 'comrade', 'state': 'sacrificial, heroic'},
#      {'name': 'Kael',
#       'role': "antagonist's enforcer",
#       'state': 'overpowered by resolve'}],
#     'goal': 'Transmit the truth despite overwhelming odds',
#     'conflict': 'Moral and physical sacrifice versus institutional betrayal',
#     'novelty_score': 0.88,
#     'coherence_score': 0.96},
#    {'event_id': 'E6',
#     'title': 'Echoes in the Hall of Records',
#     'summary': "Weeks later, Garrick stands before a military tribunal, presenting the recovered evidence. The high-ranking officer is arrested, and a formal pardon is issued for Garrick and Tarn's unit. Garrick leaves, haunted but free.",
#     'time': 'One month later',
#     'location': 'Capital city war council chamber',
#     'characters': [{'name': 'Garrick',
#       'role': 'protagonist',
#       'state': 'weary, vindicated, solitary'},
#      {'name': 'Tarn', 'role': 'comrade', 'state': 'deceased, remembered'},
#      {'name': 'High-Ranking Officer',
#       'role': 'traitor',
#       'state': 'arrested and disgraced'}],
#     'goal': 'Secure justice for the betrayed unit',
#     'conflict': 'Confronting systemic corruption with irrefutable proof',
#     'novelty_score': 0.7,
#     'coherence_score': 0.94}],
#   'edges': [{'type': 'causal',
#     'source_event_id': 'E1',
#     'target_event_id': 'E2',
#     'rationale': "The discovery of the battalion insignia in E1 heightens Garrick's suspicion, making him more alert and attuned to anomalies during watch, which leads to his detection of coded whispers in E2."},
#    {'type': 'temporal',
#     'source_event_id': 'E1',
#     'target_event_id': 'E2',
#     'rationale': 'E1 occurs at nightfall and sets up the campsite; E2 takes place at midnight, representing a direct chronological progression in the same location vicinity.'},
#    {'type': 'causal',
#     'source_event_id': 'E2',
#     'target_event_id': 'E3',
#     'rationale': 'Garrick’s suspicion from overhearing coded phrases in E2 motivates the pair to remain vigilant and investigate their surroundings at dawn, leading them to discover the blood trail and dying scout in E3.'},
#    {'type': 'temporal',
#     'source_event_id': 'E2',
#     'target_event_id': 'E3',
#     'rationale': 'E2 occurs at midnight, followed by E3 at dawn, maintaining a natural time sequence as the night transitions into morning.'},
#    {'type': 'causal',
#     'source_event_id': 'E3',
#     'target_event_id': 'E4',
#     'rationale': "The incriminating message obtained from the dying scout in E3 reveals the identity of the traitor, prompting Garrick and Tarn to flee with the evidence—directly triggering the ambush by the traitor's forces in E4."},
#    {'type': 'thematic',
#     'source_event_id': 'E3',
#     'target_event_id': 'E5',
#     'rationale': 'Both events center on revealing the truth despite personal cost: E3 uncovers the betrayal through a dying messenger, while E5 culminates in transmitting that truth through sacrifice.'},
#    {'type': 'causal',
#     'source_event_id': 'E4',
#     'target_event_id': 'E5',
#     'rationale': 'The ambush in E4 forces Garrick and Tarn into retreat, cornering them at the abandoned signal tower where they make their final stand in E5.'},
#    {'type': 'temporal',
#     'source_event_id': 'E4',
#     'target_event_id': 'E5',
#     'rationale': 'E4 takes place in the morning and directly precedes E5 in late morning, showing continuous escalation within a single day.'},
#    {'type': 'causal',
#     'source_event_id': 'E5',
#     'target_event_id': 'E6',
#     'rationale': "The flare launched in E5 successfully alerts allied forces, enabling Garrick to later present the evidence at the tribunal in E6, resulting in the traitor's arrest."},
#    {'type': 'temporal',
#     'source_event_id': 'E5',
#     'target_event_id': 'E6',
#     'rationale': 'E5 concludes with the signal being sent; E6 occurs one month later, representing the delayed but logical aftermath of that transmission.'},
#    {'type': 'thematic',
#     'source_event_id': 'E1',
#     'target_event_id': 'E6',
#     'rationale': 'Both events bookend the arc of betrayal and justice: E1 introduces the theme of internal treachery, while E6 resolves it through institutional accountability.'},
#    {'type': 'thematic',
#     'source_event_id': 'E4',
#     'target_event_id': 'E6',
#     'rationale': 'E4 represents the peak of physical conflict against the traitor’s enforcers, while E6 represents the peak of moral and systemic confrontation—both are pivotal moments in opposing the corruption introduced earlier.'}]},
#  'sub_events': [{'sub_event_id': 'E1_S1',
#    'parent_event_id': 'E1',
#    'title': 'Setting the Perimeter',
#    'summary': "Garrick methodically inspects the rocky pass for signs of recent movement, kicking aside snow to reveal disturbed earth and a partial boot print that doesn't match their unit’s pattern. He silently marks the location with a small cairn, deciding not to alert Tarn yet.",
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'weary but alert'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'injured but loyal'}]},
#   {'sub_event_id': 'E1_S2',
#    'parent_event_id': 'E1',
#    'title': 'The Insignia in the Frost',
#    'summary': "While gathering firewood, Tarn's hand brushes against a half-frozen rock where a tarnished battalion insignia is wedged—its edges deliberately scratched, a forbidden sign of dishonor. He stares at it in silence, then pockets it, his breath shallow with dread.",
#    'characters': [{'name': 'Tarn',
#      'role': 'comrade',
#      'state': 'injured but loyal'},
#     {'name': 'Garrick', 'role': 'protagonist', 'state': 'weary but alert'}]},
#   {'sub_event_id': 'E1_S3',
#    'parent_event_id': 'E1',
#    'title': 'Shared Silence Over Fire',
#    'summary': "The two sit by the meager flame, exchanging few words. Garrick notices Tarn’s trembling hand as he grips his side wound. When Garrick asks about the insignia, Tarn hesitates—then whispers a name: 'Varek.' Both know he was last seen commanding rear guard… hundreds of miles from this pass.",
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'weary but alert'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'injured but loyal'}]},
#   {'sub_event_id': 'E1_S4',
#    'parent_event_id': 'E1',
#    'title': 'The Watch Begins',
#    'summary': "Garrick takes first watch, scanning the ridgeline through a cracked field glass. A flicker of motion—too smooth for wind-tossed ice—catches his eye. He adjusts focus, but sees nothing. Behind him, Tarn mutters in fevered sleep: 'Don’t trust the signal… they’re already inside.'",
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'weary but alert'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'injured but loyal'}]},
#   {'sub_event_id': 'E1_S5',
#    'parent_event_id': 'E1',
#    'title': 'Buried Orders',
#    'summary': 'Before lying down, Garrick digs into his pack and retrieves a sealed orders pouch, its wax broken. He recalls finding it on a dead courier during the retreat—a message rerouting their unit into the ambush zone, signed with his own commander’s seal. He burns it without speaking, watching the ash rise like guilt.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'weary but alert'}]},
#   {'sub_event_id': 'E2_S1',
#    'parent_event_id': 'E2',
#    'title': 'The Watch Begins',
#    'summary': 'Garrick takes the midnight watch, wrapping himself in a frost-stiffened cloak as he scans the snow-blanketed ridge. The wind howls through narrow fissures in the rock, creating an eerie chorus that masks all but the most deliberate sounds. He checks Tarn’s bandages and finds the wound seeping again—concern gnaws at him, sharpening his senses. A faint crunch, almost swallowed by the wind, makes him turn. Nothing moves. Yet the air feels watched.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'tense and suspicious'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'asleep, vulnerable'}]},
#   {'sub_event_id': 'E2_S2',
#    'parent_event_id': 'E2',
#    'title': 'Whispers in the Static',
#    'summary': "As a gust funnels through a limestone chimney above camp, it produces a low, rhythmic moan. Garrick nearly dismisses it—until he catches a fragmented phrase: '...vector nine... secure the pass...'—the cadence unmistakably matching the unit’s encrypted field code. He freezes, breath clouding in sharp bursts. He listens for minutes more. Another burst: '...target still alive...' The words vanish with the wind, leaving doubt—is it nature, hallucination, or hunters closing in?",
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'tense and suspicious'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'asleep, vulnerable'}]},
#   {'sub_event_id': 'E2_S3',
#    'parent_event_id': 'E2',
#    'title': 'False Alarm and Hidden Mark',
#    'summary': "Convinced of enemy presence, Garrick readies his rifle and creeps toward the ridge’s edge. He spots a dark shape shifting in the mist—only to realize it’s a tattered banner, half-buried in snow, bearing the insignia of their own battalion. He retrieves it, pulse racing. Scratched into the metal clasp: a series of tally marks and the letter 'K'. He recalls Kael, the captain’s enforcer, rarely seen at camp. Was this planted? A warning? Or a trap?",
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'tense and suspicious'}]},
#   {'sub_event_id': 'E2_S4',
#    'parent_event_id': 'E2',
#    'title': 'Silent Decision',
#    'summary': 'Returning to camp, Garrick hesitates to wake Tarn. The injury slows him, and panic could worsen it. Instead, he quietly packs their most vital supplies into a smaller satchel, prepping for a rapid escape. He hides a spare pistol beneath a rock near the trailhead, marking it with a subtle scratch—just in case they’re separated. He stares into the dark pass, now seeing not just terrain, but a net tightening around them.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'tense and suspicious'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'asleep, vulnerable'}]},
#   {'sub_event_id': 'E2_S5',
#    'parent_event_id': 'E2',
#    'title': 'Echo Response',
#    'summary': "Testing his theory, Garrick uses a broken signal mirror to flash a brief, coded pulse toward the ridge—'status check' in battalion hand-signal shorthand. Minutes pass. Then, a flicker answers from a distant outcrop: three quick flashes. Not wind. Not chance. They are not alone. And worse—they are recognized.",
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'tense and suspicious'}]},
#   {'sub_event_id': 'E3_S1',
#    'parent_event_id': 'E3',
#    'title': 'Frostbitten Trail',
#    'summary': "At first light, Garrick and Tarn spot a faint smear of blood on the ice near their camp—quickly fading in the rising wind. Tarn insists it's worth following despite his worsening injury, suspecting it might be one of their missing scouts. Garrick reluctantly agrees, marking their path with broken arrowheads to avoid getting lost in the whiteout.",
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'cautious and burdened'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'weakening but insistent'}]},
#   {'sub_event_id': 'E3_S2',
#    'parent_event_id': 'E3',
#    'title': 'Whispers Beneath Ice',
#    'summary': 'The trail leads into a narrow fissure in the ravine wall, half-hidden by frozen mist. Inside, they hear shallow breathing beneath a thin crust of ice. Garrick breaks through with his blade, revealing a half-buried scout from their unit, his leg trapped and body numb. The man clutches a sealed oilskin pouch against his chest.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'shocked and urgent'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'exhausted but focused'},
#     {'name': 'Dying Scout',
#      'role': 'messenger',
#      'state': 'frozen and delirious'}]},
#   {'sub_event_id': 'E3_S3',
#    'parent_event_id': 'E3',
#    'title': 'Last Words in Code',
#    'summary': "The scout regains brief lucidity and speaks in fragmented officer cipher—naming 'Commander Veyne' as the one who ordered the ambush and burned the rear guard. With his final strength, he presses the oilskin pouch into Tarn’s hand, whispering 'Burn it if you're followed.' His eyes glaze over before he can say more.",
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'horrified and enraged'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'solemn and resolute'},
#     {'name': 'Dying Scout', 'role': 'messenger', 'state': 'deceased'}]},
#   {'sub_event_id': 'E3_S4',
#    'parent_event_id': 'E3',
#    'title': 'Signs of Pursuit',
#    'summary': 'As they exit the crevice, Garrick notices fresh boot prints in the snow—too large to be the scout’s, and aligned with military spacing. He finds a snapped wire tap hidden in the rocks nearby, confirming surveillance. They realize the enemy knows they have the message and may already be moving to intercept.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'hyper-vigilant and calculating'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'pained but alert'}]},
#   {'sub_event_id': 'E3_S5',
#    'parent_event_id': 'E3',
#    'title': 'Decision at the Divide',
#    'summary': 'Facing two paths—one steep but concealed, the other wide and fast but exposed—Garrick and Tarn argue over their route. Tarn insists on speed to deliver the message, while Garrick fears a trap. They ultimately choose the narrow ridge, unaware that Kael’s ambush team is already converging on the high pass ahead.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'torn between caution and urgency'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'determined despite pain'}]},
#   {'sub_event_id': 'E4_S1',
#    'parent_event_id': 'E4',
#    'title': 'The Ice Gorge Approach',
#    'summary': 'Garrick and Tarn navigate a narrow ice gorge, their breath fogging in the frigid air. Garrick notices disturbed snow patterns—recent footprints veering off the main path, too many for a patrol. He signals Tarn to move quietly, suspecting an ambush. Tarn stumbles, his wound reopening, leaving a faint smear of blood on the ice—a trail they can’t afford.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'battle-hardened and desperate'},
#     {'name': 'Tarn',
#      'role': 'comrade',
#      'state': 'gravely wounded but fighting'}]},
#   {'sub_event_id': 'E4_S2',
#    'parent_event_id': 'E4',
#    'title': 'First Shot, Frozen Echo',
#    'summary': 'A sniper’s bullet cracks through the silence, shattering ice above Garrick’s head. The shot was deliberate—meant to miss. It’s a signal. From concealed positions along the ridge, Kael’s squad opens fire with controlled bursts, herding the two toward a dead-end crevasse. Garrick drags Tarn behind a frozen boulder, realizing the ambush was planned around their escape route—not chance.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'battle-hardened and desperate'},
#     {'name': 'Tarn',
#      'role': 'comrade',
#      'state': 'gravely wounded but fighting'},
#     {'name': 'Kael',
#      'role': "antagonist's enforcer",
#      'state': 'ruthless and efficient'}]},
#   {'sub_event_id': 'E4_S3',
#    'parent_event_id': 'E4',
#    'title': 'Tarn’s Last Stand at the Chasm',
#    'summary': 'Cornered at the chasm’s edge, Tarn pushes Garrick toward a narrow ledge beneath the ice wall, shouting that he’ll hold them off. Using the last of his strength, he triggers a small avalanche with a well-placed grenade, collapsing the central path and forcing Kael’s men to regroup. As Kael emerges alone, cold fury in his eyes, Tarn raises his sidearm—one round left.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'battle-hardened and desperate'},
#     {'name': 'Tarn',
#      'role': 'comrade',
#      'state': 'gravely wounded but fighting'},
#     {'name': 'Kael',
#      'role': "antagonist's enforcer",
#      'state': 'ruthless and efficient'}]},
#   {'sub_event_id': 'E4_S4',
#    'parent_event_id': 'E4',
#    'title': 'Message in the Snow',
#    'summary': "As Garrick crawls beneath the ice shelf, he presses the incriminating message into a waterproof capsule and lodges it deep in a glacial fissure, marking it with Tarn’s dog tag. If he doesn’t make it, someone might still find it. Above, gunfire ceases. Silence. Then Kael’s voice echoes: 'You don’t have to die for a lie, Garrick.' The words plant a seed of doubt—was the message forged?",
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'battle-hardened and desperate'},
#     {'name': 'Kael',
#      'role': "antagonist's enforcer",
#      'state': 'ruthless and efficient'}]},
#   {'sub_event_id': 'E4_S5',
#    'parent_event_id': 'E4',
#    'title': 'The Flare Path Revealed',
#    'summary': "Garrick escapes the gorge and spots the distant silhouette of the abandoned signal tower on the ridge. A memory flashes—Tarn once mentioned it during training: 'Old beacon, one flare charge left. Lights up half the valley.' Hope ignites. He clutches the detonator in his pocket, vowing to send the truth skyward—even if it costs everything.",
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'grieving but resolute'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'sacrificial, heroic'}]},
#   {'sub_event_id': 'E5_S1',
#    'parent_event_id': 'E5',
#    'title': 'The Last Ammunition Inventory',
#    'summary': 'As the sound of approaching boots echoes through the icy canyon, Garrick and Tarn retreat to the crumbling signal tower. With grim urgency, they take stock of their dwindling supplies—only three rounds left for Garrick’s rifle, a half-empty magazine for Tarn’s sidearm, and a single emergency flare. Tarn hides the incriminating message inside his coat, stitching it into the lining with frozen fingers. He insists Garrick promise to fire the flare even if he falls.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'desperate but focused'},
#     {'name': 'Tarn',
#      'role': 'comrade',
#      'state': 'gravely wounded, determined'}]},
#   {'sub_event_id': 'E5_S2',
#    'parent_event_id': 'E5',
#    'title': 'Kael’s Voice from the Wind',
#    'summary': 'From the ridge above, Kael uses a stolen command frequency to broadcast a distorted voice recording of the high-ranking officer ordering Garrick and Tarn’s execution ‘for desertion.’ The ploy is meant to sow doubt and delay their final act. Tarn nearly hesitates, questioning if the betrayal was ever real—but Garrick smashes the radio, shouting that the officer’s voice lacks its telltale stutter, a detail only inner-circle troops would know.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'furious and resolute'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'doubtful, then resolved'},
#     {'name': 'Kael',
#      'role': "antagonist's enforcer",
#      'state': 'manipulative and in control'}]},
#   {'sub_event_id': 'E5_S3',
#    'parent_event_id': 'E5',
#    'title': 'Tarn’s Final Stand at the Gate',
#    'summary': 'As enemy forces close in, Tarn drags himself to the tower’s rusted entrance, propping a shattered beam against the door. When the enforcers breach the gate, he triggers a makeshift avalanche by shooting weakened ice columns overhead, burying two attackers and buying Garrick critical seconds. Mortally wounded by return fire, Tarn collapses, whispering the unit’s motto—‘Truth outlives blood’—before going still.',
#    'characters': [{'name': 'Tarn',
#      'role': 'comrade',
#      'state': 'sacrificial, heroic'},
#     {'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'grief-stricken but driven'},
#     {'name': 'Kael',
#      'role': "antagonist's enforcer",
#      'state': 'ruthless, momentarily thwarted'}]},
#   {'sub_event_id': 'E5_S4',
#    'parent_event_id': 'E5',
#    'title': 'Ignition of the Beacon',
#    'summary': 'Alone and bleeding, Garrick climbs the tower’s unstable gantry. He primes the old flare mechanism, inscribing the traitor’s name and coordinates onto the canister with his knife. As Kael reaches the base, Garrick fires the flare—it streaks skyward in a blinding arc, visible for miles. The signal pulses not just location, but a coded distress tag known only to loyal intelligence cells, ensuring the message will be authenticated.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'resolute, transcendent'},
#     {'name': 'Kael',
#      'role': "antagonist's enforcer",
#      'state': 'defeated in purpose'}]},
#   {'sub_event_id': 'E5_S5',
#    'parent_event_id': 'E5',
#    'title': 'Echoes Across the Range',
#    'summary': 'The flare detonates high above, casting red light across the snow. In distant valleys, hidden watchers—a rogue scout, a defecting courier, and an old signals operator—see the burst and recognize the unique signature. One activates a dormant relay; another begins transcribing the code. Unseen, the truth starts spreading beyond military channels, seeding future resistance.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'vindicated, isolated'},
#     {'name': 'Rogue Scout', 'role': 'future ally', 'state': 'awakened'},
#     {'name': 'Defecting Courier',
#      'role': 'future informant',
#      'state': 'decisive'},
#     {'name': 'Signals Operator',
#      'role': 'future contact',
#      'state': 'alert and ready'}]},
#   {'sub_event_id': 'E6_S1',
#    'parent_event_id': 'E6',
#    'title': 'The Weight of Silence Before Testimony',
#    'summary': 'Minutes before the tribunal convenes, Garrick stands alone in a dim antechamber beneath the war council hall. A junior clerk, trembling, hands him a sealed envelope—left behind by Tarn during their last supply run—containing personal letters and a hidden ledger page with encrypted financial transfers implicating other officers. The revelation forces Garrick to consider whether justice can be contained within one trial.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'solemn and burdened'},
#     {'name': 'Junior Clerk',
#      'role': 'messenger',
#      'state': 'nervous but resolute'}]},
#   {'sub_event_id': 'E6_S2',
#    'parent_event_id': 'E6',
#    'title': "Tarn's Final Words Read Aloud",
#    'summary': 'At the start of the tribunal, Garrick requests permission to read Tarn’s final letter—not just as evidence, but as testimony. As he reads aloud Tarn’s reflections on loyalty, duty, and the cost of silence, several officers in attendance shift uncomfortably, including a previously neutral adjutant who later discreetly signals willingness to cooperate with further investigations.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'grieving but composed'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'deceased, remembered'},
#     {'name': 'Council Members',
#      'role': 'authority figures',
#      'state': 'divided in reaction'}]},
#   {'sub_event_id': 'E6_S3',
#    'parent_event_id': 'E6',
#    'title': 'The Traitor’s Defiance',
#    'summary': 'When confronted with the incriminating message recovered from the dying scout, the high-ranking officer does not deny his actions but instead argues that the campaign’s failure necessitated sacrifice—and that men like Garrick were always expendable. His cold logic stirs murmurs among the council, exposing deep ideological fractures within the military leadership.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'outraged but restrained'},
#     {'name': 'High-Ranking Officer',
#      'role': 'traitor',
#      'state': 'defiant and unrepentant'},
#     {'name': 'Military Tribunal Panel',
#      'role': 'judges',
#      'state': 'unsettled and divided'}]},
#   {'sub_event_id': 'E6_S4',
#    'parent_event_id': 'E6',
#    'title': 'Pardon Amidst Shadows',
#    'summary': "The tribunal issues a formal pardon for Garrick and Tarn’s unit, publicly clearing their names. However, as records are updated, an unseen archivist makes a coded notation in the margins—marking Garrick’s file with a black sigil used for 'potential destabilizers.' This quiet act hints at ongoing surveillance and future targeting despite official vindication.",
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'vindicated but uneasy'},
#     {'name': 'Archivist',
#      'role': 'background observer',
#      'state': 'covert and methodical'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'honored posthumously'}]},
#   {'sub_event_id': 'E6_S5',
#    'parent_event_id': 'E6',
#    'title': 'A Letter Sent Into the Wild',
#    'summary': 'After leaving the chamber, Garrick does not return to barracks. Instead, he writes a short, unsanctioned letter addressed to surviving members of scattered loyalist cells—using cipher patterns known only to trusted operatives. He hides it inside a departing courier pigeon’s capsule, setting in motion a clandestine network that may one day resist deeper corruption.',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'solitary and purposeful'}]}],
#  'chapters': [{'chapter_id': 1,
#    'title': 'The Weight of Ash and Silence',
#    'summary': 'A nonlinear opening that begins in medias res with Garrick preparing for the tribunal, then flashes back to the quiet horror of the mountain camp. The chapter weaves early signs of betrayal—disturbed earth, a hidden insignia, burned orders—with the emotional weight of loyalty and doubt, establishing the psychological toll of war and deception.',
#    'sub_event_ids': ['E6_S1', 'E1_S1', 'E1_S2', 'E1_S3', 'E1_S5', 'E1_S4']},
#   {'chapter_id': 2,
#    'title': 'Voices in the Wind, Marks in the Snow',
#    'summary': 'Told almost entirely in real-time from Garrick’s midnight watch, this chapter builds paranoia through fragmented whispers, ambiguous signals, and subtle traps. Flash-forwards are embedded as fleeting memories—Garrick briefly hallucinates Tarn falling, the flare igniting—heightening tension as he deciphers whether the enemy is real or inside his mind.',
#    'sub_event_ids': ['E2_S1', 'E2_S2', 'E2_S3', 'E2_S5', 'E2_S4']},
#   {'chapter_id': 3,
#    'title': 'Blood Beneath the Ice',
#    'summary': 'A tightly paced chapter following the discovery of the dying scout and the incriminating message. Through sharp sensory details and rising urgency, it contrasts the fragility of truth with the brutality of pursuit, culminating in the fateful decision at the divide—where hope and doom converge.',
#    'sub_event_ids': ['E3_S1', 'E3_S2', 'E3_S3', 'E3_S4', 'E3_S5']},
#   {'chapter_id': 4,
#    'title': 'The Ambush in Frozen Time',
#    'summary': 'Presented with a fractured timeline, this chapter intercuts the ice gorge ambush with flashbacks triggered by each gunshot: Tarn’s laughter during training, the forged reroute order, Varek’s last transmission. The chaos of battle merges with memory, revealing how the past has weaponized the present.',
#    'sub_event_ids': ['E4_S1',
#     'E1_S3',
#     'E4_S2',
#     'E3_S3',
#     'E4_S3',
#     'E4_S4',
#     'E4_S5']},
#   {'chapter_id': 5,
#    'title': 'Truth in Fire and Smoke',
#    'summary': 'From the crumbling signal tower to the sky-rending flare, this chapter unfolds chronologically but deepens its impact with visions—Tarn alive, giving orders; Kael hesitating; the beacon lighting a rebellion across the range. The final stand becomes mythic, transcending survival to become legacy.',
#    'sub_event_ids': ['E5_S1', 'E5_S2', 'E5_S3', 'E5_S4', 'E5_S5']},
#   {'chapter_id': 6,
#    'title': 'Echoes That Never Fade',
#    'summary': 'The aftermath refracts justice through silence, bureaucracy, and quiet resistance. Rather than conclude with closure, this chapter uses the tribunal not as an end but a beginning—revealing deeper corruption, honoring Tarn’s voice, and launching a secret network that ensures the truth will outlive institutions.',
#    'sub_event_ids': ['E6_S2', 'E6_S3', 'E6_S4', 'E6_S5', 'E5_S5']}]}

# %%
with open('story_plan.json', 'w') as f:
    json.dump(story_plan.model_dump(), f, indent=2, ensure_ascii=False)

# %%
import os

from autogen_ext.models.openai import OpenAIChatCompletionClient
from loguru import logger

from story_writer.schemas.outline_schemas import EventGraph
from story_writer.workflow import OutlineBuilder


# Build story outline
async def main(model_client, premise, k_candidates, max_val, max_events) -> EventGraph:
    outline_builder = OutlineBuilder(
        model_client=model_client,
        k_candidates=k_candidates,
        max_val=max_val,
        max_events=max_events,
    )
    return await outline_builder.build_outline(premise)


# Set up a Qwen model client
model_client = OpenAIChatCompletionClient(
    model="qwen3-235b-a22b-instruct-2507",
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
    api_key=os.environ["DASHSCOPE_API_KEY"],
    model_info={
        "vision": False,
        "function_calling": True,
        "json_output": True,
        "family": "unknown",
        "structured_output": False,
    },
    temperature=0.7,
)
premise = "A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them."
k_candidates = 3
max_val = 2
max_events = 30


logger.add(sink="logs/{time}.log")

event_graph = await main(
    model_client=model_client,
    premise=premise,
    k_candidates=k_candidates,
    max_val=max_val,
    max_events=max_events,
)
event_graph.model_dump()
# Out:
# 2025-09-16 11:23:34.096 | INFO     | story_writer.workflow.outline_builder:build_outline:379 - Building story outline...
# 2025-09-16 11:23:34.097 | INFO     | story_writer.workflow.outline_builder:build_outline:390 - Checking completeness, current iteration 1, max iterations 60
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# PartialEventList:
# []
#
# Task:
# - Analyze whether the outline is complete.
# - Return a JSON object following the EventCompleteness schema.
#
# ---------- TextMessage (event_completeness_agent) ----------
# {
#   "complete": false,
#   "reason": "The Partial Event List is empty, so no narrative events have been outlined. There is no beginning, conflict, climax, or resolution. No character actions or developments are present.",
#   "missing_elements": [
#     "Beginning",
#     "Conflict",
#     "Climax",
#     "Resolution",
#     "Character appearances",
#     "Causal chain"
#   ]
# }
# 2025-09-16 11:23:38.179 | INFO     | story_writer.workflow.outline_builder:build_outline:399 - Outline incomplete: The Partial Event List is empty, so no narrative events have been outlined. There is no beginning, conflict, climax, or resolution. No character actions or developments are present.
# 2025-09-16 11:23:38.180 | INFO     | story_writer.workflow.outline_builder:build_outline:402 - Generating candidate events, current iteration 1, max iterations 60
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# PartialEventList:
# []
#
# CompletenessStatus:
# Reason: The Partial Event List is empty, so no narrative events have been outlined. There is no beginning, conflict, climax, or resolution. No character actions or developments are present.
# MissingElements: ['Beginning', 'Conflict', 'Climax', 'Resolution', 'Character appearances', 'Causal chain']
#
# Requirements:
# - Produce up to 3 candidate events
# - Focus especially on covering the missing elements listed in CompletenessStatus
# - Ensure consistency with the existing PartialEventList
#
# ---------- ModelClientStreamingChunkEvent (event_seed_agent) ----------
# [
#   {
#     "event_id": "E1",
#     "title": "Campsite Under Moonlight",
#     "summary": "The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.",
#     "time": "Nightfall",
#     "location": "Rocky mountain pass",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "weary but alert"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "injured but loyal"
#       }
#     ],
#     "goal": "Rest and assess their next move",
#     "conflict": "Discovering evidence of betrayal within their ranks",
#     "novelty_score": 0.7,
#     "coherence_score": 0.95
#   },
#   {
#     "event_id": "E2",
#     "title": "Whispers in the Snow",
#     "summary": "While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.",
#     "time": "Midnight",
#     "location": "High ridge near camp",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "tense and suspicious"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "asleep, vulnerable"
#       }
#     ],
#     "goal": "Identify the source of the mysterious signals",
#     "conflict": "Paranoia and the threat of ambush by former allies",
#     "novelty_score": 0.8,
#     "coherence_score": 0.9
#   },
#   {
#     "event_id": "E3",
#     "title": "Blood Trail at Dawn",
#     "summary": "At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.",
#     "time": "Dawn",
#     "location": "Frozen ravine",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "determined and vengeful"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "weakening from injury"
#       },
#       {
#         "name": "Dying Scout",
#         "role": "messenger",
#         "state": "near death"
#       }
#     ],
#     "goal": "Uncover the truth behind the betrayal",
#     "conflict": "Race against time to survive and expose the traitor",
#     "novelty_score": 0.85,
#     "coherence_score": 0.92
#   }
# ]
# 2025-09-16 11:23:51.743 | INFO     | story_writer.workflow.outline_builder:build_outline:412 - Generated 3 event candidates
# 2025-09-16 11:23:51.744 | INFO     | story_writer.workflow.outline_builder:build_outline:413 - Event candidates: [Event(event_id='E1', title='Campsite Under Moonlight', summary='The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.', time='Nightfall', location='Rocky mountain pass', characters=[Character(name='Garrick', role='protagonist', state='weary but alert'), Character(name='Tarn', role='comrade', state='injured but loyal')], goal='Rest and assess their next move', conflict='Discovering evidence of betrayal within their ranks', novelty_score=0.7, coherence_score=0.95), Event(event_id='E2', title='Whispers in the Snow', summary='While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.', time='Midnight', location='High ridge near camp', characters=[Character(name='Garrick', role='protagonist', state='tense and suspicious'), Character(name='Tarn', role='comrade', state='asleep, vulnerable')], goal='Identify the source of the mysterious signals', conflict='Paranoia and the threat of ambush by former allies', novelty_score=0.8, coherence_score=0.9), Event(event_id='E3', title='Blood Trail at Dawn', summary='At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.', time='Dawn', location='Frozen ravine', characters=[Character(name='Garrick', role='protagonist', state='determined and vengeful'), Character(name='Tarn', role='comrade', state='weakening from injury'), Character(name='Dying Scout', role='messenger', state='near death')], goal='Uncover the truth behind the betrayal', conflict='Race against time to survive and expose the traitor', novelty_score=0.85, coherence_score=0.92)]
# 2025-09-16 11:23:51.744 | INFO     | story_writer.workflow.outline_builder:build_outline:420 - Validating candidate events, 1/2
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# PartialEventList:
# []
#
# Candidates:
# [{'event_id': 'E1', 'title': 'Campsite Under Moonlight', 'summary': 'The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.', 'time': 'Nightfall', 'location': 'Rocky mountain pass', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'weary but alert'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'injured but loyal'}], 'goal': 'Rest and assess their next move', 'conflict': 'Discovering evidence of betrayal within their ranks', 'novelty_score': 0.7, 'coherence_score': 0.95}, {'event_id': 'E2', 'title': 'Whispers in the Snow', 'summary': 'While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.', 'time': 'Midnight', 'location': 'High ridge near camp', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'tense and suspicious'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'asleep, vulnerable'}], 'goal': 'Identify the source of the mysterious signals', 'conflict': 'Paranoia and the threat of ambush by former allies', 'novelty_score': 0.8, 'coherence_score': 0.9}, {'event_id': 'E3', 'title': 'Blood Trail at Dawn', 'summary': 'At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.', 'time': 'Dawn', 'location': 'Frozen ravine', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'determined and vengeful'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'weakening from injury'}, {'name': 'Dying Scout', 'role': 'messenger', 'state': 'near death'}], 'goal': 'Uncover the truth behind the betrayal', 'conflict': 'Race against time to survive and expose the traitor', 'novelty_score': 0.85, 'coherence_score': 0.92}]
#
# ---------- TextMessage (event_validator_agent) ----------
# [
#   {
#     "event_id": "E1",
#     "suggestion": "Event is consistent with the premise and introduces key evidence of betrayal. No prior events to conflict with. Character states and setting align with the narrative. Valid and coherent.",
#     "valid": true
#   },
#   {
#     "event_id": "E2",
#     "suggestion": "Maintains temporal and character state consistency. Builds on E1's revelation through escalating tension. The use of unit-specific code phrases supports causal plausibility. No world-rule violations. Valid.",
#     "valid": true
#   },
#   {
#     "event_id": "E3",
#     "suggestion": "Logically follows from E1 and E2, advancing the betrayal plot with new evidence. Character states are consistent (Tarn weakening, Garrick driven). Introduction of dying scout is plausible. No redundancy or rule violations. Valid.",
#     "valid": true
#   }
# ]
# 2025-09-16 11:23:56.901 | INFO     | story_writer.workflow.outline_builder:build_outline:428 - Event validations: [EventValidate(event_id='E1', suggestion='Event is consistent with the premise and introduces key evidence of betrayal. No prior events to conflict with. Character states and setting align with the narrative. Valid and coherent.', valid=True), EventValidate(event_id='E2', suggestion="Maintains temporal and character state consistency. Builds on E1's revelation through escalating tension. The use of unit-specific code phrases supports causal plausibility. No world-rule violations. Valid.", valid=True), EventValidate(event_id='E3', suggestion='Logically follows from E1 and E2, advancing the betrayal plot with new evidence. Character states are consistent (Tarn weakening, Garrick driven). Introduction of dying scout is plausible. No redundancy or rule violations. Valid.', valid=True)]
# 2025-09-16 11:23:56.901 | INFO     | story_writer.workflow.outline_builder:build_outline:448 - Accepted 3 events, 3 total
# 2025-09-16 11:23:56.902 | INFO     | story_writer.workflow.outline_builder:build_outline:390 - Checking completeness, current iteration 2, max iterations 60
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# PartialEventList:
# [{'event_id': 'E1', 'title': 'Campsite Under Moonlight', 'summary': 'The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.', 'time': 'Nightfall', 'location': 'Rocky mountain pass', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'weary but alert'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'injured but loyal'}], 'goal': 'Rest and assess their next move', 'conflict': 'Discovering evidence of betrayal within their ranks', 'novelty_score': 0.7, 'coherence_score': 0.95}, {'event_id': 'E2', 'title': 'Whispers in the Snow', 'summary': 'While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.', 'time': 'Midnight', 'location': 'High ridge near camp', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'tense and suspicious'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'asleep, vulnerable'}], 'goal': 'Identify the source of the mysterious signals', 'conflict': 'Paranoia and the threat of ambush by former allies', 'novelty_score': 0.8, 'coherence_score': 0.9}, {'event_id': 'E3', 'title': 'Blood Trail at Dawn', 'summary': 'At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.', 'time': 'Dawn', 'location': 'Frozen ravine', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'determined and vengeful'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'weakening from injury'}, {'name': 'Dying Scout', 'role': 'messenger', 'state': 'near death'}], 'goal': 'Uncover the truth behind the betrayal', 'conflict': 'Race against time to survive and expose the traitor', 'novelty_score': 0.85, 'coherence_score': 0.92}]
#
# Task:
# - Analyze whether the outline is complete.
# - Return a JSON object following the EventCompleteness schema.
#
# ---------- TextMessage (event_completeness_agent) ----------
# {
#   "complete": false,
#   "reason": "The narrative has established a strong beginning and rising conflict, with the discovery of betrayal and a dying scout implicating a high-ranking officer. However, the climax and resolution are missing. There is no confrontation with the traitor, no resolution of the central conflict, and no closure for the protagonists' journey. Additionally, the character arcs for Garrick and Tarn remain unresolved, and the causal chain ends before reaching a payoff.",
#   "missing_elements": [
#     "Climax: confrontation with the traitor or final obstacle",
#     "Resolution: outcome of the betrayal revelation and fate of the protagonists",
#     "Character resolution: development or closure for Garrick and Tarn",
#     "Causal chain continuation: how the discovered message leads to action and consequences"
#   ]
# }
# 2025-09-16 11:24:01.402 | INFO     | story_writer.workflow.outline_builder:build_outline:399 - Outline incomplete: The narrative has established a strong beginning and rising conflict, with the discovery of betrayal and a dying scout implicating a high-ranking officer. However, the climax and resolution are missing. There is no confrontation with the traitor, no resolution of the central conflict, and no closure for the protagonists' journey. Additionally, the character arcs for Garrick and Tarn remain unresolved, and the causal chain ends before reaching a payoff.
# 2025-09-16 11:24:01.406 | INFO     | story_writer.workflow.outline_builder:build_outline:402 - Generating candidate events, current iteration 2, max iterations 60
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# PartialEventList:
# [{'event_id': 'E1', 'title': 'Campsite Under Moonlight', 'summary': 'The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.', 'time': 'Nightfall', 'location': 'Rocky mountain pass', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'weary but alert'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'injured but loyal'}], 'goal': 'Rest and assess their next move', 'conflict': 'Discovering evidence of betrayal within their ranks', 'novelty_score': 0.7, 'coherence_score': 0.95}, {'event_id': 'E2', 'title': 'Whispers in the Snow', 'summary': 'While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.', 'time': 'Midnight', 'location': 'High ridge near camp', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'tense and suspicious'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'asleep, vulnerable'}], 'goal': 'Identify the source of the mysterious signals', 'conflict': 'Paranoia and the threat of ambush by former allies', 'novelty_score': 0.8, 'coherence_score': 0.9}, {'event_id': 'E3', 'title': 'Blood Trail at Dawn', 'summary': 'At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.', 'time': 'Dawn', 'location': 'Frozen ravine', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'determined and vengeful'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'weakening from injury'}, {'name': 'Dying Scout', 'role': 'messenger', 'state': 'near death'}], 'goal': 'Uncover the truth behind the betrayal', 'conflict': 'Race against time to survive and expose the traitor', 'novelty_score': 0.85, 'coherence_score': 0.92}]
#
# CompletenessStatus:
# Reason: The narrative has established a strong beginning and rising conflict, with the discovery of betrayal and a dying scout implicating a high-ranking officer. However, the climax and resolution are missing. There is no confrontation with the traitor, no resolution of the central conflict, and no closure for the protagonists' journey. Additionally, the character arcs for Garrick and Tarn remain unresolved, and the causal chain ends before reaching a payoff.
# MissingElements: ['Climax: confrontation with the traitor or final obstacle', 'Resolution: outcome of the betrayal revelation and fate of the protagonists', 'Character resolution: development or closure for Garrick and Tarn', 'Causal chain continuation: how the discovered message leads to action and consequences']
#
# Requirements:
# - Produce up to 3 candidate events
# - Focus especially on covering the missing elements listed in CompletenessStatus
# - Ensure consistency with the existing PartialEventList
#
# ---------- ModelClientStreamingChunkEvent (event_seed_agent) ----------
# [
#   {
#     "event_id": "E4",
#     "title": "Ambush at the Pass",
#     "summary": "As Garrick and Tarn attempt to escape the mountains with the incriminating message, they are ambushed by a covert squad led by the traitor's loyal enforcer. A brutal firefight ensues in the narrow ice gorge.",
#     "time": "Morning",
#     "location": "Ice-covered mountain pass",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "battle-hardened and desperate"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "gravely wounded but fighting"
#       },
#       {
#         "name": "Kael",
#         "role": "antagonist's enforcer",
#         "state": "ruthless and efficient"
#       }
#     ],
#     "goal": "Survive the ambush and deliver the message to loyal forces",
#     "conflict": "Direct confrontation with the traitor's forces before the truth can be exposed",
#     "novelty_score": 0.75,
#     "coherence_score": 0.93
#   },
#   {
#     "event_id": "E5",
#     "title": "Final Stand at the Beacon",
#     "summary": "Cornered at an old signal tower, Garrick uses the last of their supplies to ignite a flare, revealing both their location and the traitor's name to a distant allied outpost. Tarn sacrifices himself to hold off the attackers.",
#     "time": "Late Morning",
#     "location": "Abandoned signal tower",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "grieving but resolute"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "sacrificial, heroic"
#       },
#       {
#         "name": "Kael",
#         "role": "antagonist's enforcer",
#         "state": "overpowered by resolve"
#       }
#     ],
#     "goal": "Transmit the truth despite overwhelming odds",
#     "conflict": "Moral and physical sacrifice versus institutional betrayal",
#     "novelty_score": 0.88,
#     "coherence_score": 0.96
#   },
#   {
#     "event_id": "E6",
#     "title": "Echoes in the Hall of Records",
#     "summary": "Weeks later, Garrick stands before a military tribunal, presenting the recovered evidence. The high-ranking officer is arrested, and a formal pardon is issued for Garrick and Tarn's unit. Garrick leaves, haunted but free.",
#     "time": "One month later",
#     "location": "Capital city war council chamber",
#     "characters": [
#       {
#         "name": "Garrick",
#         "role": "protagonist",
#         "state": "weary, vindicated, solitary"
#       },
#       {
#         "name": "Tarn",
#         "role": "comrade",
#         "state": "deceased, remembered"
#       },
#       {
#         "name": "High-Ranking Officer",
#         "role": "traitor",
#         "state": "arrested and disgraced"
#       }
#     ],
#     "goal": "Secure justice for the betrayed unit",
#     "conflict": "Confronting systemic corruption with irrefutable proof",
#     "novelty_score": 0.7,
#     "coherence_score": 0.94
#   }
# ]
# 2025-09-16 11:24:16.544 | INFO     | story_writer.workflow.outline_builder:build_outline:412 - Generated 3 event candidates
# 2025-09-16 11:24:16.546 | INFO     | story_writer.workflow.outline_builder:build_outline:413 - Event candidates: [Event(event_id='E4', title='Ambush at the Pass', summary="As Garrick and Tarn attempt to escape the mountains with the incriminating message, they are ambushed by a covert squad led by the traitor's loyal enforcer. A brutal firefight ensues in the narrow ice gorge.", time='Morning', location='Ice-covered mountain pass', characters=[Character(name='Garrick', role='protagonist', state='battle-hardened and desperate'), Character(name='Tarn', role='comrade', state='gravely wounded but fighting'), Character(name='Kael', role="antagonist's enforcer", state='ruthless and efficient')], goal='Survive the ambush and deliver the message to loyal forces', conflict="Direct confrontation with the traitor's forces before the truth can be exposed", novelty_score=0.75, coherence_score=0.93), Event(event_id='E5', title='Final Stand at the Beacon', summary="Cornered at an old signal tower, Garrick uses the last of their supplies to ignite a flare, revealing both their location and the traitor's name to a distant allied outpost. Tarn sacrifices himself to hold off the attackers.", time='Late Morning', location='Abandoned signal tower', characters=[Character(name='Garrick', role='protagonist', state='grieving but resolute'), Character(name='Tarn', role='comrade', state='sacrificial, heroic'), Character(name='Kael', role="antagonist's enforcer", state='overpowered by resolve')], goal='Transmit the truth despite overwhelming odds', conflict='Moral and physical sacrifice versus institutional betrayal', novelty_score=0.88, coherence_score=0.96), Event(event_id='E6', title='Echoes in the Hall of Records', summary="Weeks later, Garrick stands before a military tribunal, presenting the recovered evidence. The high-ranking officer is arrested, and a formal pardon is issued for Garrick and Tarn's unit. Garrick leaves, haunted but free.", time='One month later', location='Capital city war council chamber', characters=[Character(name='Garrick', role='protagonist', state='weary, vindicated, solitary'), Character(name='Tarn', role='comrade', state='deceased, remembered'), Character(name='High-Ranking Officer', role='traitor', state='arrested and disgraced')], goal='Secure justice for the betrayed unit', conflict='Confronting systemic corruption with irrefutable proof', novelty_score=0.7, coherence_score=0.94)]
# 2025-09-16 11:24:16.546 | INFO     | story_writer.workflow.outline_builder:build_outline:420 - Validating candidate events, 1/2
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# PartialEventList:
# [{'event_id': 'E1', 'title': 'Campsite Under Moonlight', 'summary': 'The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.', 'time': 'Nightfall', 'location': 'Rocky mountain pass', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'weary but alert'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'injured but loyal'}], 'goal': 'Rest and assess their next move', 'conflict': 'Discovering evidence of betrayal within their ranks', 'novelty_score': 0.7, 'coherence_score': 0.95}, {'event_id': 'E2', 'title': 'Whispers in the Snow', 'summary': 'While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.', 'time': 'Midnight', 'location': 'High ridge near camp', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'tense and suspicious'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'asleep, vulnerable'}], 'goal': 'Identify the source of the mysterious signals', 'conflict': 'Paranoia and the threat of ambush by former allies', 'novelty_score': 0.8, 'coherence_score': 0.9}, {'event_id': 'E3', 'title': 'Blood Trail at Dawn', 'summary': 'At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.', 'time': 'Dawn', 'location': 'Frozen ravine', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'determined and vengeful'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'weakening from injury'}, {'name': 'Dying Scout', 'role': 'messenger', 'state': 'near death'}], 'goal': 'Uncover the truth behind the betrayal', 'conflict': 'Race against time to survive and expose the traitor', 'novelty_score': 0.85, 'coherence_score': 0.92}]
#
# Candidates:
# [{'event_id': 'E4', 'title': 'Ambush at the Pass', 'summary': "As Garrick and Tarn attempt to escape the mountains with the incriminating message, they are ambushed by a covert squad led by the traitor's loyal enforcer. A brutal firefight ensues in the narrow ice gorge.", 'time': 'Morning', 'location': 'Ice-covered mountain pass', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'battle-hardened and desperate'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'gravely wounded but fighting'}, {'name': 'Kael', 'role': "antagonist's enforcer", 'state': 'ruthless and efficient'}], 'goal': 'Survive the ambush and deliver the message to loyal forces', 'conflict': "Direct confrontation with the traitor's forces before the truth can be exposed", 'novelty_score': 0.75, 'coherence_score': 0.93}, {'event_id': 'E5', 'title': 'Final Stand at the Beacon', 'summary': "Cornered at an old signal tower, Garrick uses the last of their supplies to ignite a flare, revealing both their location and the traitor's name to a distant allied outpost. Tarn sacrifices himself to hold off the attackers.", 'time': 'Late Morning', 'location': 'Abandoned signal tower', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'grieving but resolute'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'sacrificial, heroic'}, {'name': 'Kael', 'role': "antagonist's enforcer", 'state': 'overpowered by resolve'}], 'goal': 'Transmit the truth despite overwhelming odds', 'conflict': 'Moral and physical sacrifice versus institutional betrayal', 'novelty_score': 0.88, 'coherence_score': 0.96}, {'event_id': 'E6', 'title': 'Echoes in the Hall of Records', 'summary': "Weeks later, Garrick stands before a military tribunal, presenting the recovered evidence. The high-ranking officer is arrested, and a formal pardon is issued for Garrick and Tarn's unit. Garrick leaves, haunted but free.", 'time': 'One month later', 'location': 'Capital city war council chamber', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'weary, vindicated, solitary'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'deceased, remembered'}, {'name': 'High-Ranking Officer', 'role': 'traitor', 'state': 'arrested and disgraced'}], 'goal': 'Secure justice for the betrayed unit', 'conflict': 'Confronting systemic corruption with irrefutable proof', 'novelty_score': 0.7, 'coherence_score': 0.94}]
#
# ---------- TextMessage (event_validator_agent) ----------
# [
#   {
#     "event_id": "E4",
#     "suggestion": "The event is consistent with prior events: Garrick and Tarn are still alive, actively fleeing with the message, and face escalating threats. The antagonist's enforcer Kael is plausibly introduced as part of the traitor's network. The location and timing follow naturally from E3. No redundancy or rule violations.",
#     "valid": true
#   },
#   {
#     "event_id": "E5",
#     "suggestion": "Tarn's heroic sacrifice is consistent with his loyal character state and the escalating conflict. The event causally follows E4's ambush and fulfills the goal of exposing the truth. The use of the beacon is plausible within the mountain setting. Emotional and narrative coherence is high. No redundancy.",
#     "valid": true
#   },
#   {
#     "event_id": "E6",
#     "suggestion": "Garrick surviving to present evidence is consistent with E5. Tarn is correctly listed as deceased, reflecting his sacrifice. The tribunal setting and outcome align with the premise of systemic betrayal. Time jump is acceptable and adds closure. No world-rule violations or redundancy.",
#     "valid": true
#   }
# ]
# 2025-09-16 11:24:25.972 | INFO     | story_writer.workflow.outline_builder:build_outline:428 - Event validations: [EventValidate(event_id='E4', suggestion="The event is consistent with prior events: Garrick and Tarn are still alive, actively fleeing with the message, and face escalating threats. The antagonist's enforcer Kael is plausibly introduced as part of the traitor's network. The location and timing follow naturally from E3. No redundancy or rule violations.", valid=True), EventValidate(event_id='E5', suggestion="Tarn's heroic sacrifice is consistent with his loyal character state and the escalating conflict. The event causally follows E4's ambush and fulfills the goal of exposing the truth. The use of the beacon is plausible within the mountain setting. Emotional and narrative coherence is high. No redundancy.", valid=True), EventValidate(event_id='E6', suggestion='Garrick surviving to present evidence is consistent with E5. Tarn is correctly listed as deceased, reflecting his sacrifice. The tribunal setting and outcome align with the premise of systemic betrayal. Time jump is acceptable and adds closure. No world-rule violations or redundancy.', valid=True)]
# 2025-09-16 11:24:25.973 | INFO     | story_writer.workflow.outline_builder:build_outline:448 - Accepted 3 events, 6 total
# 2025-09-16 11:24:25.973 | INFO     | story_writer.workflow.outline_builder:build_outline:390 - Checking completeness, current iteration 3, max iterations 60
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# PartialEventList:
# [{'event_id': 'E1', 'title': 'Campsite Under Moonlight', 'summary': 'The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.', 'time': 'Nightfall', 'location': 'Rocky mountain pass', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'weary but alert'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'injured but loyal'}], 'goal': 'Rest and assess their next move', 'conflict': 'Discovering evidence of betrayal within their ranks', 'novelty_score': 0.7, 'coherence_score': 0.95}, {'event_id': 'E2', 'title': 'Whispers in the Snow', 'summary': 'While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.', 'time': 'Midnight', 'location': 'High ridge near camp', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'tense and suspicious'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'asleep, vulnerable'}], 'goal': 'Identify the source of the mysterious signals', 'conflict': 'Paranoia and the threat of ambush by former allies', 'novelty_score': 0.8, 'coherence_score': 0.9}, {'event_id': 'E3', 'title': 'Blood Trail at Dawn', 'summary': 'At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.', 'time': 'Dawn', 'location': 'Frozen ravine', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'determined and vengeful'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'weakening from injury'}, {'name': 'Dying Scout', 'role': 'messenger', 'state': 'near death'}], 'goal': 'Uncover the truth behind the betrayal', 'conflict': 'Race against time to survive and expose the traitor', 'novelty_score': 0.85, 'coherence_score': 0.92}, {'event_id': 'E4', 'title': 'Ambush at the Pass', 'summary': "As Garrick and Tarn attempt to escape the mountains with the incriminating message, they are ambushed by a covert squad led by the traitor's loyal enforcer. A brutal firefight ensues in the narrow ice gorge.", 'time': 'Morning', 'location': 'Ice-covered mountain pass', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'battle-hardened and desperate'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'gravely wounded but fighting'}, {'name': 'Kael', 'role': "antagonist's enforcer", 'state': 'ruthless and efficient'}], 'goal': 'Survive the ambush and deliver the message to loyal forces', 'conflict': "Direct confrontation with the traitor's forces before the truth can be exposed", 'novelty_score': 0.75, 'coherence_score': 0.93}, {'event_id': 'E5', 'title': 'Final Stand at the Beacon', 'summary': "Cornered at an old signal tower, Garrick uses the last of their supplies to ignite a flare, revealing both their location and the traitor's name to a distant allied outpost. Tarn sacrifices himself to hold off the attackers.", 'time': 'Late Morning', 'location': 'Abandoned signal tower', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'grieving but resolute'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'sacrificial, heroic'}, {'name': 'Kael', 'role': "antagonist's enforcer", 'state': 'overpowered by resolve'}], 'goal': 'Transmit the truth despite overwhelming odds', 'conflict': 'Moral and physical sacrifice versus institutional betrayal', 'novelty_score': 0.88, 'coherence_score': 0.96}, {'event_id': 'E6', 'title': 'Echoes in the Hall of Records', 'summary': "Weeks later, Garrick stands before a military tribunal, presenting the recovered evidence. The high-ranking officer is arrested, and a formal pardon is issued for Garrick and Tarn's unit. Garrick leaves, haunted but free.", 'time': 'One month later', 'location': 'Capital city war council chamber', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'weary, vindicated, solitary'}, {'name': 'Tarn ...
#
# Task:
# - Analyze whether the outline is complete.
# - Return a JSON object following the EventCompleteness schema.
#
# ---------- TextMessage (event_completeness_agent) ----------
# {
#   "complete": true,
#   "reason": "The narrative arc is fully realized: the story begins with the discovery of betrayal (E1), builds tension through suspicion and pursuit (E2-E3), reaches a climax in the ambush and final stand where Tarn sacrifices himself (E4-E5), and concludes with resolution as justice is served at the tribunal (E6). All major characters from the premise—Garrick, Tarn, and the implied traitor (represented by the high-ranking officer and his enforcer Kael)—are present and their arcs are addressed. The causal chain is strong: evidence of betrayal leads to investigation, pursuit, confrontation, sacrifice, and ultimate vindication. There are no significant gaps in logic or structure.",
#   "missing_elements": []
# }
# 2025-09-16 11:24:30.244 | INFO     | story_writer.workflow.outline_builder:build_outline:397 - Outline complete: The narrative arc is fully realized: the story begins with the discovery of betrayal (E1), builds tension through suspicion and pursuit (E2-E3), reaches a climax in the ambush and final stand where Tarn sacrifices himself (E4-E5), and concludes with resolution as justice is served at the tribunal (E6). All major characters from the premise—Garrick, Tarn, and the implied traitor (represented by the high-ranking officer and his enforcer Kael)—are present and their arcs are addressed. The causal chain is strong: evidence of betrayal leads to investigation, pursuit, confrontation, sacrifice, and ultimate vindication. There are no significant gaps in logic or structure.
# 2025-09-16 11:24:30.244 | INFO     | story_writer.workflow.outline_builder:build_outline:472 - Accepted 6 events, generating relations
# ---------- TextMessage (user) ----------
# Premise:
# A battle-hardened veteran and his loyal comrade travel through a mountain range after a failed campaign. Strange signs suggest someone betrayed them.
#
# Event List:
# [{'event_id': 'E1', 'title': 'Campsite Under Moonlight', 'summary': 'The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.', 'time': 'Nightfall', 'location': 'Rocky mountain pass', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'weary but alert'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'injured but loyal'}], 'goal': 'Rest and assess their next move', 'conflict': 'Discovering evidence of betrayal within their ranks', 'novelty_score': 0.7, 'coherence_score': 0.95}, {'event_id': 'E2', 'title': 'Whispers in the Snow', 'summary': 'While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.', 'time': 'Midnight', 'location': 'High ridge near camp', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'tense and suspicious'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'asleep, vulnerable'}], 'goal': 'Identify the source of the mysterious signals', 'conflict': 'Paranoia and the threat of ambush by former allies', 'novelty_score': 0.8, 'coherence_score': 0.9}, {'event_id': 'E3', 'title': 'Blood Trail at Dawn', 'summary': 'At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.', 'time': 'Dawn', 'location': 'Frozen ravine', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'determined and vengeful'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'weakening from injury'}, {'name': 'Dying Scout', 'role': 'messenger', 'state': 'near death'}], 'goal': 'Uncover the truth behind the betrayal', 'conflict': 'Race against time to survive and expose the traitor', 'novelty_score': 0.85, 'coherence_score': 0.92}, {'event_id': 'E4', 'title': 'Ambush at the Pass', 'summary': "As Garrick and Tarn attempt to escape the mountains with the incriminating message, they are ambushed by a covert squad led by the traitor's loyal enforcer. A brutal firefight ensues in the narrow ice gorge.", 'time': 'Morning', 'location': 'Ice-covered mountain pass', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'battle-hardened and desperate'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'gravely wounded but fighting'}, {'name': 'Kael', 'role': "antagonist's enforcer", 'state': 'ruthless and efficient'}], 'goal': 'Survive the ambush and deliver the message to loyal forces', 'conflict': "Direct confrontation with the traitor's forces before the truth can be exposed", 'novelty_score': 0.75, 'coherence_score': 0.93}, {'event_id': 'E5', 'title': 'Final Stand at the Beacon', 'summary': "Cornered at an old signal tower, Garrick uses the last of their supplies to ignite a flare, revealing both their location and the traitor's name to a distant allied outpost. Tarn sacrifices himself to hold off the attackers.", 'time': 'Late Morning', 'location': 'Abandoned signal tower', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'grieving but resolute'}, {'name': 'Tarn', 'role': 'comrade', 'state': 'sacrificial, heroic'}, {'name': 'Kael', 'role': "antagonist's enforcer", 'state': 'overpowered by resolve'}], 'goal': 'Transmit the truth despite overwhelming odds', 'conflict': 'Moral and physical sacrifice versus institutional betrayal', 'novelty_score': 0.88, 'coherence_score': 0.96}, {'event_id': 'E6', 'title': 'Echoes in the Hall of Records', 'summary': "Weeks later, Garrick stands before a military tribunal, presenting the recovered evidence. The high-ranking officer is arrested, and a formal pardon is issued for Garrick and Tarn's unit. Garrick leaves, haunted but free.", 'time': 'One month later', 'location': 'Capital city war council chamber', 'characters': [{'name': 'Garrick', 'role': 'protagonist', 'state': 'weary, vindicated, solitary'}, {'name': 'Tarn ...
#
# Requirements:
# - Generate relations for the entire set of events.
# - Prioritize creating causal chains to cover narrative arcs (e.g., build-up to climax).
# - Ensure relations enhance coherence and novelty based on event scores.
#
# ---------- TextMessage (event_relation_agent) ----------
# [
#   {
#     "type": "causal",
#     "source_event_id": "E1",
#     "target_event_id": "E2",
#     "rationale": "The discovery of the battalion insignia in E1 heightens Garrick's suspicion, making him more alert and attuned to anomalies during watch, which leads to his detection of coded whispers in E2."
#   },
#   {
#     "type": "temporal",
#     "source_event_id": "E1",
#     "target_event_id": "E2",
#     "rationale": "E1 occurs at nightfall and sets up the campsite; E2 takes place at midnight, representing a direct chronological progression in the same location vicinity."
#   },
#   {
#     "type": "causal",
#     "source_event_id": "E2",
#     "target_event_id": "E3",
#     "rationale": "Garrick’s suspicion from overhearing coded phrases in E2 motivates the pair to remain vigilant and investigate their surroundings at dawn, leading them to discover the blood trail and dying scout in E3."
#   },
#   {
#     "type": "temporal",
#     "source_event_id": "E2",
#     "target_event_id": "E3",
#     "rationale": "E2 occurs at midnight, followed by E3 at dawn, maintaining a natural time sequence as the night transitions into morning."
#   },
#   {
#     "type": "causal",
#     "source_event_id": "E3",
#     "target_event_id": "E4",
#     "rationale": "The incriminating message obtained from the dying scout in E3 reveals the identity of the traitor, prompting Garrick and Tarn to flee with the evidence—directly triggering the ambush by the traitor's forces in E4."
#   },
#   {
#     "type": "thematic",
#     "source_event_id": "E3",
#     "target_event_id": "E5",
#     "rationale": "Both events center on revealing the truth despite personal cost: E3 uncovers the betrayal through a dying messenger, while E5 culminates in transmitting that truth through sacrifice."
#   },
#   {
#     "type": "causal",
#     "source_event_id": "E4",
#     "target_event_id": "E5",
#     "rationale": "The ambush in E4 forces Garrick and Tarn into retreat, cornering them at the abandoned signal tower where they make their final stand in E5."
#   },
#   {
#     "type": "temporal",
#     "source_event_id": "E4",
#     "target_event_id": "E5",
#     "rationale": "E4 takes place in the morning and directly precedes E5 in late morning, showing continuous escalation within a single day."
#   },
#   {
#     "type": "causal",
#     "source_event_id": "E5",
#     "target_event_id": "E6",
#     "rationale": "The flare launched in E5 successfully alerts allied forces, enabling Garrick to later present the evidence at the tribunal in E6, resulting in the traitor's arrest."
#   },
#   {
#     "type": "temporal",
#     "source_event_id": "E5",
#     "target_event_id": "E6",
#     "rationale": "E5 concludes with the signal being sent; E6 occurs one month later, representing the delayed but logical aftermath of that transmission."
#   },
#   {
#     "type": "thematic",
#     "source_event_id": "E1",
#     "target_event_id": "E6",
#     "rationale": "Both events bookend the arc of betrayal and justice: E1 introduces the theme of internal treachery, while E6 resolves it through institutional accountability."
#   },
#   {
#     "type": "thematic",
#     "source_event_id": "E4",
#     "target_event_id": "E6",
#     "rationale": "E4 represents the peak of physical conflict against the traitor’s enforcers, while E6 represents the peak of moral and systemic confrontation—both are pivotal moments in opposing the corruption introduced earlier."
#   }
# ]
# 2025-09-16 11:24:51.491 | INFO     | story_writer.workflow.outline_builder:build_outline:477 - Generated 12 relations
# {'nodes': [{'event_id': 'E1',
#    'title': 'Campsite Under Moonlight',
#    'summary': 'The veteran and his comrade set up camp in a rocky pass, wary after the disastrous campaign. They find a discarded insignia from their own battalion, suggesting betrayal.',
#    'time': 'Nightfall',
#    'location': 'Rocky mountain pass',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'weary but alert'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'injured but loyal'}],
#    'goal': 'Rest and assess their next move',
#    'conflict': 'Discovering evidence of betrayal within their ranks',
#    'novelty_score': 0.7,
#    'coherence_score': 0.95},
#   {'event_id': 'E2',
#    'title': 'Whispers in the Snow',
#    'summary': 'While on watch, Garrick overhears faint voices in the wind—speaking code phrases only officers from their unit knew. He suspects they are being tracked.',
#    'time': 'Midnight',
#    'location': 'High ridge near camp',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'tense and suspicious'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'asleep, vulnerable'}],
#    'goal': 'Identify the source of the mysterious signals',
#    'conflict': 'Paranoia and the threat of ambush by former allies',
#    'novelty_score': 0.8,
#    'coherence_score': 0.9},
#   {'event_id': 'E3',
#    'title': 'Blood Trail at Dawn',
#    'summary': 'At first light, the two follow a trail of blood leading to a hidden crevice where a dying scout from their unit lies, clutching a message implicating a high-ranking officer in the betrayal.',
#    'time': 'Dawn',
#    'location': 'Frozen ravine',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'determined and vengeful'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'weakening from injury'},
#     {'name': 'Dying Scout', 'role': 'messenger', 'state': 'near death'}],
#    'goal': 'Uncover the truth behind the betrayal',
#    'conflict': 'Race against time to survive and expose the traitor',
#    'novelty_score': 0.85,
#    'coherence_score': 0.92},
#   {'event_id': 'E4',
#    'title': 'Ambush at the Pass',
#    'summary': "As Garrick and Tarn attempt to escape the mountains with the incriminating message, they are ambushed by a covert squad led by the traitor's loyal enforcer. A brutal firefight ensues in the narrow ice gorge.",
#    'time': 'Morning',
#    'location': 'Ice-covered mountain pass',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'battle-hardened and desperate'},
#     {'name': 'Tarn',
#      'role': 'comrade',
#      'state': 'gravely wounded but fighting'},
#     {'name': 'Kael',
#      'role': "antagonist's enforcer",
#      'state': 'ruthless and efficient'}],
#    'goal': 'Survive the ambush and deliver the message to loyal forces',
#    'conflict': "Direct confrontation with the traitor's forces before the truth can be exposed",
#    'novelty_score': 0.75,
#    'coherence_score': 0.93},
#   {'event_id': 'E5',
#    'title': 'Final Stand at the Beacon',
#    'summary': "Cornered at an old signal tower, Garrick uses the last of their supplies to ignite a flare, revealing both their location and the traitor's name to a distant allied outpost. Tarn sacrifices himself to hold off the attackers.",
#    'time': 'Late Morning',
#    'location': 'Abandoned signal tower',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'grieving but resolute'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'sacrificial, heroic'},
#     {'name': 'Kael',
#      'role': "antagonist's enforcer",
#      'state': 'overpowered by resolve'}],
#    'goal': 'Transmit the truth despite overwhelming odds',
#    'conflict': 'Moral and physical sacrifice versus institutional betrayal',
#    'novelty_score': 0.88,
#    'coherence_score': 0.96},
#   {'event_id': 'E6',
#    'title': 'Echoes in the Hall of Records',
#    'summary': "Weeks later, Garrick stands before a military tribunal, presenting the recovered evidence. The high-ranking officer is arrested, and a formal pardon is issued for Garrick and Tarn's unit. Garrick leaves, haunted but free.",
#    'time': 'One month later',
#    'location': 'Capital city war council chamber',
#    'characters': [{'name': 'Garrick',
#      'role': 'protagonist',
#      'state': 'weary, vindicated, solitary'},
#     {'name': 'Tarn', 'role': 'comrade', 'state': 'deceased, remembered'},
#     {'name': 'High-Ranking Officer',
#      'role': 'traitor',
#      'state': 'arrested and disgraced'}],
#    'goal': 'Secure justice for the betrayed unit',
#    'conflict': 'Confronting systemic corruption with irrefutable proof',
#    'novelty_score': 0.7,
#    'coherence_score': 0.94}],
#  'edges': [{'type': 'causal',
#    'source_event_id': 'E1',
#    'target_event_id': 'E2',
#    'rationale': "The discovery of the battalion insignia in E1 heightens Garrick's suspicion, making him more alert and attuned to anomalies during watch, which leads to his detection of coded whispers in E2."},
#   {'type': 'temporal',
#    'source_event_id': 'E1',
#    'target_event_id': 'E2',
#    'rationale': 'E1 occurs at nightfall and sets up the campsite; E2 takes place at midnight, representing a direct chronological progression in the same location vicinity.'},
#   {'type': 'causal',
#    'source_event_id': 'E2',
#    'target_event_id': 'E3',
#    'rationale': 'Garrick’s suspicion from overhearing coded phrases in E2 motivates the pair to remain vigilant and investigate their surroundings at dawn, leading them to discover the blood trail and dying scout in E3.'},
#   {'type': 'temporal',
#    'source_event_id': 'E2',
#    'target_event_id': 'E3',
#    'rationale': 'E2 occurs at midnight, followed by E3 at dawn, maintaining a natural time sequence as the night transitions into morning.'},
#   {'type': 'causal',
#    'source_event_id': 'E3',
#    'target_event_id': 'E4',
#    'rationale': "The incriminating message obtained from the dying scout in E3 reveals the identity of the traitor, prompting Garrick and Tarn to flee with the evidence—directly triggering the ambush by the traitor's forces in E4."},
#   {'type': 'thematic',
#    'source_event_id': 'E3',
#    'target_event_id': 'E5',
#    'rationale': 'Both events center on revealing the truth despite personal cost: E3 uncovers the betrayal through a dying messenger, while E5 culminates in transmitting that truth through sacrifice.'},
#   {'type': 'causal',
#    'source_event_id': 'E4',
#    'target_event_id': 'E5',
#    'rationale': 'The ambush in E4 forces Garrick and Tarn into retreat, cornering them at the abandoned signal tower where they make their final stand in E5.'},
#   {'type': 'temporal',
#    'source_event_id': 'E4',
#    'target_event_id': 'E5',
#    'rationale': 'E4 takes place in the morning and directly precedes E5 in late morning, showing continuous escalation within a single day.'},
#   {'type': 'causal',
#    'source_event_id': 'E5',
#    'target_event_id': 'E6',
#    'rationale': "The flare launched in E5 successfully alerts allied forces, enabling Garrick to later present the evidence at the tribunal in E6, resulting in the traitor's arrest."},
#   {'type': 'temporal',
#    'source_event_id': 'E5',
#    'target_event_id': 'E6',
#    'rationale': 'E5 concludes with the signal being sent; E6 occurs one month later, representing the delayed but logical aftermath of that transmission.'},
#   {'type': 'thematic',
#    'source_event_id': 'E1',
#    'target_event_id': 'E6',
#    'rationale': 'Both events bookend the arc of betrayal and justice: E1 introduces the theme of internal treachery, while E6 resolves it through institutional accountability.'},
#   {'type': 'thematic',
#    'source_event_id': 'E4',
#    'target_event_id': 'E6',
#    'rationale': 'E4 represents the peak of physical conflict against the traitor’s enforcers, while E6 represents the peak of moral and systemic confrontation—both are pivotal moments in opposing the corruption introduced earlier.'}]}

# %%
import json

with open("event_graph.json", "w", encoding="utf-8") as f:
    json.dump(event_graph.model_dump(), f, ensure_ascii=False, indent=2)
